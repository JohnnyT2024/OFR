# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-GOVE
# ### 14th June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df34 = pd.read_excel ('OFR/Amrun.xlsx')
df35 = pd.read_excel ('OFR/Gove.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df34.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  145   3.255  127.72984    144462  0.109    129518     Yes
# 1  156   4.418  127.42739    209425  0.145    129527     Yes
# 2  157   4.617  127.40511    153737  0.055    129528     Yes
# 3  171   6.834  127.31992    281217  0.254    129540     Yes
# 4  175   7.488  127.31618    118041  0.055    129544     Yes
# 5  182   8.505  127.45210    235721  0.309    129549     Yes
# 6  184   8.723  127.60602    114039  0.145    129550     Yes
# 7  257  11.122  165.80799    140486  0.127    129616     Yes
# 8  259  11.177  186.99339    963197  0.200    129617     Yes
# 9  262  11.304  186.91464    272184  0.055    129619     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      127.72984
# 1              ----      ----  ----        ----        ----      127.42739
# ...

# %%
df35.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  156   2.456  127.46779    132351  0.091    129891     Yes
# 1  161   3.309  127.18315    533231  0.200    129894     Yes
# 2  294   6.491  237.63104    174901  0.127    130019     Yes
# 3  284  11.995  186.82477    695193  0.091    130010     Yes
# 4  301  21.242  228.88670    510119  0.200    130025     Yes
# 5  310  23.932  243.33817    435724  0.073    130030     Yes
# 6  306  23.986  226.26576    165923  0.109    130027     Yes
# 7  313  23.986  243.36296    893913  0.200    130031     Yes
# 8  231  25.582  127.42295    125442  0.200    129963     Yes
# 9  323  26.966  295.02989    179778  0.073    130033     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----   ----        ----        ----      127.46779
# 1              ----      ----   ----        ----        ----      127.18315
# ...

# %%
#df33.head(10)

# %%
df34.columns = (df34.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df35.columns = (df35.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
#df33.columns = (df31.columns.str.replace('RT', 'TR_MIN')
                #.str.replace('m/z', 'FW')
                #.str.replace('Predicted Formula', 'MF')
                #.str.replace('Response', 'AREA_COUNTS'))

# %%
df34.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  145   3.255  127.72984       144462  0.109        129518     Yes  ----
# 1  156   4.418  127.42739       209425  0.145        129527     Yes  ----
# 2  157   4.617  127.40511       153737  0.055        129528     Yes  ----
# 3  171   6.834  127.31992       281217  0.254        129540     Yes  ----
# 4  175   7.488  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
df35.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  156   2.456  127.46779       132351  0.091        129891     Yes  ----
# 1  161   3.309  127.18315       533231  0.200        129894     Yes  ----
# 2  294   6.491  237.63104       174901  0.127        130019     Yes  ----
# 3  284  11.995  186.82477       695193  0.091        130010     Yes  ----
# 4  301  21.242  228.88670       510119  0.200        130025     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.46779      3        ----
# 1      ----  ----        ----        ----      127.18315      3        ----
# 2      ----  ----        ----        ----      237.63104      8        ----
# 3      ----  ----        ----        ----      186.82477      6        ----
# 4      ----  ----        ----        ----      228.88670      8        ----
#
# ...

# %%
#df33.head()

# %%
# Set TR_MIN as index for dataframe

df34.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df34.reset_index(inplace=True)

# %%
df34.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   3.255  145  127.72984       144462  0.109        129518     Yes  ----
# 1   4.418  156  127.42739       209425  0.145        129527     Yes  ----
# 2   4.617  157  127.40511       153737  0.055        129528     Yes  ----
# 3   6.834  171  127.31992       281217  0.254        129540     Yes  ----
# 4   7.488  175  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df35.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df35.reset_index(inplace=True)

# %%
df35.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   2.456  156  127.46779       132351  0.091        129891     Yes  ----
# 1   3.309  161  127.18315       533231  0.200        129894     Yes  ----
# 2   6.491  294  237.63104       174901  0.127        130019     Yes  ----
# 3  11.995  284  186.82477       695193  0.091        130010     Yes  ----
# 4  21.242  301  228.88670       510119  0.200        130025     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.46779      3        ----
# 1      ----  ----        ----        ----      127.18315      3        ----
# 2      ----  ----        ----        ----      237.63104      8        ----
# 3      ----  ----        ----        ----      186.82477      6        ----
# 4      ----  ----        ----        ----      228.88670      8        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

#df33.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
#df33.reset_index(inplace=True)

# %%
#df33.head()

# %%
df34.index
# Out:
# RangeIndex(start=0, stop=136, step=1)

# %%
df35.index
# Out:
# RangeIndex(start=0, stop=127, step=1)

# %%
#df33.index

# %%
df34.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df35.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
#df33.columns

# %%
# Select the required columns for the new DataFrame
df34 = df34[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df34.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   3.255       144462  ----  127.72984
# 1   4.418       209425  ----  127.42739
# 2   4.617       153737  ----  127.40511
# 3   6.834       281217  ----  127.31992
# 4   7.488       118041  ----  127.31618

# %%
# Select the required columns for the new DataFrame
df35 = df35[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df35.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   2.456       132351  ----  127.46779
# 1   3.309       533231  ----  127.18315
# 2   6.491       174901  ----  237.63104
# 3  11.995       695193  ----  186.82477
# 4  21.242       510119  ----  228.88670

# %%
# Select the required columns for the new DataFrame
#df33 = df33[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
#df33.head()

# %%
df34.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       136 non-null    float64
#  1   AREA_COUNTS  136 non-null    int64
#  2   MF           136 non-null    object
#  3   FW           136 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.4+ KB

# %%
df35.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       127 non-null    float64
#  1   AREA_COUNTS  127 non-null    int64
#  2   MF           127 non-null    object
#  3   FW           127 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting
plt.scatter(df34['FW'], df34['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.scatter(df35['FW'], df35['AREA_COUNTS'], label='-ve GOVE', color='red')



# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df34, df35)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df34_binned = bin_and_sum(df34)
df35_binned = bin_and_sum(df35)


# Plot the binned sums versus 'FW'
plt.plot(df34_binned['FW_bin'], df34_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df35_binned['FW_bin'], df35_binned['AREA_COUNTS'], label='-ve GOVE', color='red', marker='o')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_42576\4071812758.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_42576\4071812758.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()

# %%
# Check format of the columns df34
df34.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df35
df35.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df34_binned = bin_and_sum(df34)
df35_binned = bin_and_sum(df35)


# Applying the scaling factors
df34_binned['AREA_COUNTS'] *= 1.000
df35_binned['AREA_COUNTS'] *= 1.0958


# Plotting the binned and scaled sums versus 'FW'
plt.plot(df34_binned['FW_bin'], df34_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df35_binned['FW_bin'], df35_binned['AREA_COUNTS'], label='-ve GOVE', color='red', marker='o')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_42576\1725187318.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_42576\1725187318.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()

# %%
#Check the summary of binned data for df34
df34_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 0   100.16091   14530394.0
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 13  425.16091   13550226.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check the summary of binned data for df3
df35_binned.head(27)
# Out:
#        FW_bin   AREA_COUNTS
# 0   100.11754  1.571867e+07
# 1   125.11754  1.334991e+06
# 2   150.11754  0.000000e+00
# 3   175.11754  7.617925e+05
# 4   200.11754  0.000000e+00
# 5   225.11754  2.389480e+06
# 6   250.11754  1.195337e+06
# 7   275.11754  3.879559e+05
# 8   300.11754  9.906602e+05
# 9   325.11754  3.068195e+06
# 10  350.11754  1.487998e+06
# 11  375.11754  0.000000e+00
# 12  400.11754  0.000000e+00
# 13  425.11754  1.457602e+07
# 14  450.11754  9.308996e+05
# 15  475.11754  5.166127e+05
# 16  500.11754  0.000000e+00
# 17  525.11754  0.000000e+00
# 18  550.11754  0.000000e+00
# 19  575.11754  0.000000e+00
# 20  600.11754  0.000000e+00
# 21  625.11754  1.629208e+06
# 22  650.11754  5.193358e+05
# 23  675.11754  3.587529e+06
# 24  700.11754  0.000000e+00
# 25  725.11754  0.000000e+00
# 26  750.11754  1.501619e+05

# %%
#New dataframe of df34 binned data by dropping row [0] and row [13] 
df34_binned = df34_binned.drop([0,13])

# %%
#New dataframe of df35 binned data by dropping row [0] and row [13] 
df35_binned = df35_binned.drop([0,13])

# %%
#Check if drop() function worked by calling df34.head() again
df34_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check if drop() function worked by calling df35.head() again
df35_binned.head(25)
# Out:
#        FW_bin   AREA_COUNTS
# 1   125.11754  1.334991e+06
# 2   150.11754  0.000000e+00
# 3   175.11754  7.617925e+05
# 4   200.11754  0.000000e+00
# 5   225.11754  2.389480e+06
# 6   250.11754  1.195337e+06
# 7   275.11754  3.879559e+05
# 8   300.11754  9.906602e+05
# 9   325.11754  3.068195e+06
# 10  350.11754  1.487998e+06
# 11  375.11754  0.000000e+00
# 12  400.11754  0.000000e+00
# 14  450.11754  9.308996e+05
# 15  475.11754  5.166127e+05
# 16  500.11754  0.000000e+00
# 17  525.11754  0.000000e+00
# 18  550.11754  0.000000e+00
# 19  575.11754  0.000000e+00
# 20  600.11754  0.000000e+00
# 21  625.11754  1.629208e+06
# 22  650.11754  5.193358e+05
# 23  675.11754  3.587529e+06
# 24  700.11754  0.000000e+00
# 25  725.11754  0.000000e+00
# 26  750.11754  1.501619e+05

# %%
# Plotting the binned and scaled sums versus 'FW' for adjusted graps
plt.plot(df34_binned['FW_bin'], df34_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df35_binned['FW_bin'], df35_binned['AREA_COUNTS'], label='-ve GOVE', color='red', marker='o')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-AMRUN275-AMRUN350
# ### 14th June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df36 = pd.read_excel ('OFR/Amrun.xlsx')
df37 = pd.read_excel ('OFR/Amrun275.xlsx')
df38 = pd.read_excel ('OFR/Amrun350.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df36.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  145   3.255  127.72984    144462  0.109    129518     Yes
# 1  156   4.418  127.42739    209425  0.145    129527     Yes
# 2  157   4.617  127.40511    153737  0.055    129528     Yes
# 3  171   6.834  127.31992    281217  0.254    129540     Yes
# 4  175   7.488  127.31618    118041  0.055    129544     Yes
# 5  182   8.505  127.45210    235721  0.309    129549     Yes
# 6  184   8.723  127.60602    114039  0.145    129550     Yes
# 7  257  11.122  165.80799    140486  0.127    129616     Yes
# 8  259  11.177  186.99339    963197  0.200    129617     Yes
# 9  262  11.304  186.91464    272184  0.055    129619     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      127.72984
# 1              ----      ----  ----        ----        ----      127.42739
# ...

# %%
df37.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  149   4.599  127.32173    200075  0.109    130283     Yes
# 1  246   5.764  223.49155    132835  0.091    130367     Yes
# 2  223  11.177  186.81081    269467  0.036    130354     Yes
# 3  227  11.250  186.68852    263261  0.127    130356     Yes
# 4  231  11.976  186.70058    189165  0.127    130359     Yes
# 5  234  12.031  186.76329    364084  0.200    130360     Yes
# 6  237  12.067  186.87530    310966  0.200    130361     Yes
# 7  241  21.478  193.85275    155558  0.164    130364     Yes
# 8  259  23.913  243.52522    279913  0.055    130374     Yes
# 9  252  23.967  226.58832    149643  0.091    130372     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      127.32173
# 1              ----      ----  ----        ----        ----      223.49155
# ...

# %%
df38.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  148   1.565  127.65521    140180  0.073    125397     Yes
# 1  156   2.056  127.56700    138387  0.182    125403     Yes
# 2  293   5.710  223.67298    163853  0.200    125517     Yes
# 3  268  11.032  187.22693    166809  0.109    125500     Yes
# 4  269  11.068  187.16461    399289  0.309    125501     Yes
# 5  271  11.086  187.11659    297091  0.436    125502     Yes
# 6  274  11.159  187.09705    251641  0.254    125503     Yes
# 7  277  11.795  186.65726    191342  0.091    125506     Yes
# 8  280  11.976  186.64351    416551  0.218    125508     Yes
# 9  283  12.013  187.01855    282628  0.436    125509     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----   ----        ----        ----      127.65521
# 1              ----      ----   ----        ----        ----      127.56700
# ...

# %%
df36.columns = (df36.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df37.columns = (df37.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df38.columns = (df38.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df36.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  145   3.255  127.72984       144462  0.109        129518     Yes  ----
# 1  156   4.418  127.42739       209425  0.145        129527     Yes  ----
# 2  157   4.617  127.40511       153737  0.055        129528     Yes  ----
# 3  171   6.834  127.31992       281217  0.254        129540     Yes  ----
# 4  175   7.488  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
df37.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  149   4.599  127.32173       200075  0.109        130283     Yes  ----
# 1  246   5.764  223.49155       132835  0.091        130367     Yes  ----
# 2  223  11.177  186.81081       269467  0.036        130354     Yes  ----
# 3  227  11.250  186.68852       263261  0.127        130356     Yes  ----
# 4  231  11.976  186.70058       189165  0.127        130359     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.32173      3        ----
# 1      ----  ----        ----        ----      223.49155      8        ----
# 2      ----  ----        ----        ----      186.81081      6        ----
# 3      ----  ----        ----        ----      186.68852      6        ----
# 4      ----  ----        ----        ----      186.70058      6        ----
#
# ...

# %%
df38.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  148   1.565  127.65521       140180  0.073        125397     Yes  ----
# 1  156   2.056  127.56700       138387  0.182        125403     Yes  ----
# 2  293   5.710  223.67298       163853  0.200        125517     Yes  ----
# 3  268  11.032  187.22693       166809  0.109        125500     Yes  ----
# 4  269  11.068  187.16461       399289  0.309        125501     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.65521      3        ----
# 1      ----  ----        ----        ----      127.56700      3        ----
# 2      ----  ----        ----        ----      223.67298      8        ----
# 3      ----  ----        ----        ----      187.22693      6        ----
# 4      ----  ----        ----        ----      187.16461      6        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df36.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df36.reset_index(inplace=True)

# %%
df36.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   3.255  145  127.72984       144462  0.109        129518     Yes  ----
# 1   4.418  156  127.42739       209425  0.145        129527     Yes  ----
# 2   4.617  157  127.40511       153737  0.055        129528     Yes  ----
# 3   6.834  171  127.31992       281217  0.254        129540     Yes  ----
# 4   7.488  175  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df37.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df37.reset_index(inplace=True)

# %%
df37.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   4.599  149  127.32173       200075  0.109        130283     Yes  ----
# 1   5.764  246  223.49155       132835  0.091        130367     Yes  ----
# 2  11.177  223  186.81081       269467  0.036        130354     Yes  ----
# 3  11.250  227  186.68852       263261  0.127        130356     Yes  ----
# 4  11.976  231  186.70058       189165  0.127        130359     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.32173      3        ----
# 1      ----  ----        ----        ----      223.49155      8        ----
# 2      ----  ----        ----        ----      186.81081      6        ----
# 3      ----  ----        ----        ----      186.68852      6        ----
# 4      ----  ----        ----        ----      186.70058      6        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df38.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df38.reset_index(inplace=True)

# %%
df38.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   1.565  148  127.65521       140180  0.073        125397     Yes  ----
# 1   2.056  156  127.56700       138387  0.182        125403     Yes  ----
# 2   5.710  293  223.67298       163853  0.200        125517     Yes  ----
# 3  11.032  268  187.22693       166809  0.109        125500     Yes  ----
# 4  11.068  269  187.16461       399289  0.309        125501     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.65521      3        ----
# 1      ----  ----        ----        ----      127.56700      3        ----
# 2      ----  ----        ----        ----      223.67298      8        ----
# 3      ----  ----        ----        ----      187.22693      6        ----
# 4      ----  ----        ----        ----      187.16461      6        ----
#
# ...

# %%
df36.index
# Out:
# RangeIndex(start=0, stop=136, step=1)

# %%
df37.index
# Out:
# RangeIndex(start=0, stop=132, step=1)

# %%
df38.index
# Out:
# RangeIndex(start=0, stop=172, step=1)

# %%
df36.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df37.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df38.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df36 = df36[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df36.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   3.255       144462  ----  127.72984
# 1   4.418       209425  ----  127.42739
# 2   4.617       153737  ----  127.40511
# 3   6.834       281217  ----  127.31992
# 4   7.488       118041  ----  127.31618

# %%
# Select the required columns for the new DataFrame
df37 = df37[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df37.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   4.599       200075  ----  127.32173
# 1   5.764       132835  ----  223.49155
# 2  11.177       269467  ----  186.81081
# 3  11.250       263261  ----  186.68852
# 4  11.976       189165  ----  186.70058

# %%
# Select the required columns for the new DataFrame
df38 = df38[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df38.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   1.565       140180  ----  127.65521
# 1   2.056       138387  ----  127.56700
# 2   5.710       163853  ----  223.67298
# 3  11.032       166809  ----  187.22693
# 4  11.068       399289  ----  187.16461

# %%
df36.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       136 non-null    float64
#  1   AREA_COUNTS  136 non-null    int64
#  2   MF           136 non-null    object
#  3   FW           136 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.4+ KB

# %%
df37.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       132 non-null    float64
#  1   AREA_COUNTS  132 non-null    int64
#  2   MF           132 non-null    object
#  3   FW           132 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.3+ KB

# %%
df38.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       172 non-null    float64
#  1   AREA_COUNTS  172 non-null    int64
#  2   MF           172 non-null    object
#  3   FW           172 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.5+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting
plt.scatter(df36['FW'], df36['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.scatter(df37['FW'], df37['AREA_COUNTS'], label='-ve AMRUN 275oC', color='red')
plt.scatter(df38['FW'], df38['AREA_COUNTS'], label='-ve AMRUN 350oC', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df31, df32, df33)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df36_binned = bin_and_sum(df36)
df37_binned = bin_and_sum(df37)
df38_binned = bin_and_sum(df38)

# Plot the binned sums versus 'FW'
plt.plot(df36_binned['FW_bin'], df36_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df37_binned['FW_bin'], df37_binned['AREA_COUNTS'], label='-ve AMRUN 275oC', color='red', marker='o')
plt.plot(df38_binned['FW_bin'], df38_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_49252\699742369.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_49252\699742369.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
# Check format of the columns df31
df36.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df32
df37.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df33
df38.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df36_binned = bin_and_sum(df36)
df37_binned = bin_and_sum(df37)
df38_binned = bin_and_sum(df38)

# Applying the scaling factors
df36_binned['AREA_COUNTS'] *= 1.000
df37_binned['AREA_COUNTS'] *= 0.8995
df38_binned['AREA_COUNTS'] *= 0.4995

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df36_binned['FW_bin'], df36_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df37_binned['FW_bin'], df37_binned['AREA_COUNTS'], label='-ve AMRUN 275oC', color='red', marker='o')
plt.plot(df38_binned['FW_bin'], df38_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_49252\1764721423.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_49252\1764721423.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
#Check the summary of binned data for df36
df36_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 0   100.16091   14530394.0
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 13  425.16091   13550226.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check the summary of binned data for df37
df37_binned.head(27)
# Out:
#        FW_bin   AREA_COUNTS
# 0   100.22594  1.254015e+07
# 1   125.22594  4.556426e+05
# 2   150.22594  0.000000e+00
# 3   175.22594  1.396475e+06
# 4   200.22594  2.605618e+05
# 5   225.22594  1.232655e+06
# 6   250.22594  0.000000e+00
# 7   275.22594  1.559265e+05
# 8   300.22594  6.788589e+05
# 9   325.22594  1.773198e+06
# 10  350.22594  4.827706e+05
# 11  375.22594  9.519049e+04
# 12  400.22594  0.000000e+00
# 13  425.22594  1.875053e+07
# 14  450.22594  3.404005e+05
# 15  475.22594  3.506368e+05
# 16  500.22594  0.000000e+00
# 17  525.22594  0.000000e+00
# 18  550.22594  0.000000e+00
# 19  575.22594  0.000000e+00
# 20  600.22594  0.000000e+00
# 21  625.22594  2.927264e+06
# 22  650.22594  0.000000e+00
# 23  675.22594  3.701615e+06
# 24  700.22594  0.000000e+00
# 25  725.22594  9.251699e+05
# 26  750.22594  2.368276e+05

# %%
#Check the summary of binned data for df38
df38_binned.head(28)
# Out:
#        FW_bin   AREA_COUNTS
# 0   100.00145  8.529380e+06
# 1   125.00145  3.937009e+05
# 2   150.00145  0.000000e+00
# 3   175.00145  1.085465e+06
# 4   200.00145  8.184457e+04
# 5   225.00145  5.658006e+05
# 6   250.00145  0.000000e+00
# 7   275.00145  1.680852e+05
# 8   300.00145  1.179127e+06
# 9   325.00145  1.939391e+06
# 10  350.00145  6.082227e+05
# 11  375.00145  3.609632e+05
# 12  400.00145  7.389253e+04
# 13  425.00145  9.016044e+06
# 14  450.00145  5.658176e+05
# 15  475.00145  2.424853e+05
# 16  500.00145  0.000000e+00
# 17  525.00145  0.000000e+00
# 18  550.00145  0.000000e+00
# 19  575.00145  0.000000e+00
# 20  600.00145  0.000000e+00
# 21  625.00145  2.272465e+06
# 22  650.00145  0.000000e+00
# 23  675.00145  2.354058e+06
# 24  700.00145  0.000000e+00
# 25  725.00145  1.347599e+06

# %%
#New dataframe of df36 binned data 
df36_binned = df36_binned.drop([0,13])

# %%
#New dataframe of df 37 binned data 
df37_binned = df37_binned.drop([0,13])

# %%
#New dataframe of df38 binned data
df38_binned = df38_binned.drop([0,13])

# %%
#Check if drop() funtioc worked by calling df36.head() again
df36_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check if drop() funtioc worked by calling df37.head() again
df37_binned.head(25)
# Out:
#        FW_bin   AREA_COUNTS
# 1   125.22594  4.556426e+05
# 2   150.22594  0.000000e+00
# 3   175.22594  1.396475e+06
# 4   200.22594  2.605618e+05
# 5   225.22594  1.232655e+06
# 6   250.22594  0.000000e+00
# 7   275.22594  1.559265e+05
# 8   300.22594  6.788589e+05
# 9   325.22594  1.773198e+06
# 10  350.22594  4.827706e+05
# 11  375.22594  9.519049e+04
# 12  400.22594  0.000000e+00
# 14  450.22594  3.404005e+05
# 15  475.22594  3.506368e+05
# 16  500.22594  0.000000e+00
# 17  525.22594  0.000000e+00
# 18  550.22594  0.000000e+00
# 19  575.22594  0.000000e+00
# 20  600.22594  0.000000e+00
# 21  625.22594  2.927264e+06
# 22  650.22594  0.000000e+00
# 23  675.22594  3.701615e+06
# 24  700.22594  0.000000e+00
# 25  725.22594  9.251699e+05
# 26  750.22594  2.368276e+05

# %%
#Check if drop() function worked by calling df38.head() again
df38_binned.head(25)
# Out:
#        FW_bin   AREA_COUNTS
# 1   125.00145  3.937009e+05
# 2   150.00145  0.000000e+00
# 3   175.00145  1.085465e+06
# 4   200.00145  8.184457e+04
# 5   225.00145  5.658006e+05
# 6   250.00145  0.000000e+00
# 7   275.00145  1.680852e+05
# 8   300.00145  1.179127e+06
# 9   325.00145  1.939391e+06
# 10  350.00145  6.082227e+05
# 11  375.00145  3.609632e+05
# 12  400.00145  7.389253e+04
# 14  450.00145  5.658176e+05
# 15  475.00145  2.424853e+05
# 16  500.00145  0.000000e+00
# 17  525.00145  0.000000e+00
# 18  550.00145  0.000000e+00
# 19  575.00145  0.000000e+00
# 20  600.00145  0.000000e+00
# 21  625.00145  2.272465e+06
# 22  650.00145  0.000000e+00
# 23  675.00145  2.354058e+06
# 24  700.00145  0.000000e+00
# 25  725.00145  1.347599e+06

# %%
# Plotting the binned and scaled sums versus 'FW'
plt.plot(df36_binned['FW_bin'], df36_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df37_binned['FW_bin'], df37_binned['AREA_COUNTS'], label='-ve AMRUN 275oC', color='red', marker='o')
plt.plot(df38_binned['FW_bin'], df38_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

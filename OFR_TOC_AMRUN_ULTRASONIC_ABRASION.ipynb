# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-ULTRASONIC-ABRASION
# ### 14th June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df39 = pd.read_excel ('OFR/Amrun.xlsx')
df40 = pd.read_excel ('OFR/Abrasion.xlsx')
df41 = pd.read_excel ('OFR/Ultrasonic.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df39.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  145   3.255  127.72984    144462  0.109    129518     Yes
# 1  156   4.418  127.42739    209425  0.145    129527     Yes
# 2  157   4.617  127.40511    153737  0.055    129528     Yes
# 3  171   6.834  127.31992    281217  0.254    129540     Yes
# 4  175   7.488  127.31618    118041  0.055    129544     Yes
# 5  182   8.505  127.45210    235721  0.309    129549     Yes
# 6  184   8.723  127.60602    114039  0.145    129550     Yes
# 7  257  11.122  165.80799    140486  0.127    129616     Yes
# 8  259  11.177  186.99339    963197  0.200    129617     Yes
# 9  262  11.304  186.91464    272184  0.055    129619     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      127.72984
# 1              ----      ----  ----        ----        ----      127.42739
# ...

# %%
df40.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0   32  25.418  100.20396    124091  0.164    131023     Yes
# 1   33  25.618  100.13482    160029  0.073    131024     Yes
# 2   36  25.890  117.10342    158533  0.073    131025     Yes
# 3  221  26.114  329.59094    191863  0.127    131166     Yes
# 4   43  26.689  117.04022    905744  0.418    131031     Yes
# 5   44  26.780  100.02081   1420265  0.472    131032     Yes
# 6   46  26.835  100.00444    235858  0.309    131033     Yes
# 7   53  27.271  117.02532    208308  0.091    131038     Yes
# 8   54  27.362  100.02015    456498  0.073    131039     Yes
# 9   56  27.452  100.01173    637884  0.145    131040     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      100.20396
# 1              ----      ----  ----        ----        ----      100.13482
# ...

# %%
df41.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  194   2.747  179.43025    131146  0.091    131352     Yes
# 1  230   7.490  237.35530    121921  0.145    131378     Yes
# 2  218  10.814  186.56951    165094  0.091    131369     Yes
# 3  220  12.431  186.66486    172327  0.200    131370     Yes
# 4  222  21.605  193.37968    130113  0.073    131371     Yes
# 5   15  23.020  100.20505    210179  0.382    131219     Yes
# 6   23  26.126  100.16547    383671  0.382    131226     Yes
# 7   29  26.617  100.20721    156353  0.127    131231     Yes
# 8  233  26.856  243.95337    270577  0.218    131380     Yes
# 9   34  27.071  100.22868    315079  0.145    131235     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      179.43025
# 1              ----      ----  ----        ----        ----      237.35530
# ...

# %%
df39.columns = (df39.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df40.columns = (df40.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df41.columns = (df41.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df39.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  145   3.255  127.72984       144462  0.109        129518     Yes  ----
# 1  156   4.418  127.42739       209425  0.145        129527     Yes  ----
# 2  157   4.617  127.40511       153737  0.055        129528     Yes  ----
# 3  171   6.834  127.31992       281217  0.254        129540     Yes  ----
# 4  175   7.488  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
df40.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   32  25.418  100.20396       124091  0.164        131023     Yes  ----
# 1   33  25.618  100.13482       160029  0.073        131024     Yes  ----
# 2   36  25.890  117.10342       158533  0.073        131025     Yes  ----
# 3  221  26.114  329.59094       191863  0.127        131166     Yes  ----
# 4   43  26.689  117.04022       905744  0.418        131031     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      100.20396      2        ----
# 1      ----  ----        ----        ----      100.13482      2        ----
# 2      ----  ----        ----        ----      117.10342      2        ----
# 3      ----  ----        ----        ----      329.59094     13        ----
# 4      ----  ----        ----        ----      117.04022      2        ----
#
# ...

# %%
df41.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  194   2.747  179.43025       131146  0.091        131352     Yes  ----
# 1  230   7.490  237.35530       121921  0.145        131378     Yes  ----
# 2  218  10.814  186.56951       165094  0.091        131369     Yes  ----
# 3  220  12.431  186.66486       172327  0.200        131370     Yes  ----
# 4  222  21.605  193.37968       130113  0.073        131371     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      179.43025      5        ----
# 1      ----  ----        ----        ----      237.35530      8        ----
# 2      ----  ----        ----        ----      186.56951      6        ----
# 3      ----  ----        ----        ----      186.66486      6        ----
# 4      ----  ----        ----        ----      193.37968      6        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df39.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df39.reset_index(inplace=True)

# %%
df39.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   3.255  145  127.72984       144462  0.109        129518     Yes  ----
# 1   4.418  156  127.42739       209425  0.145        129527     Yes  ----
# 2   4.617  157  127.40511       153737  0.055        129528     Yes  ----
# 3   6.834  171  127.31992       281217  0.254        129540     Yes  ----
# 4   7.488  175  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df40.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df40.reset_index(inplace=True)

# %%
df40.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  25.418   32  100.20396       124091  0.164        131023     Yes  ----
# 1  25.618   33  100.13482       160029  0.073        131024     Yes  ----
# 2  25.890   36  117.10342       158533  0.073        131025     Yes  ----
# 3  26.114  221  329.59094       191863  0.127        131166     Yes  ----
# 4  26.689   43  117.04022       905744  0.418        131031     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      100.20396      2        ----
# 1      ----  ----        ----        ----      100.13482      2        ----
# 2      ----  ----        ----        ----      117.10342      2        ----
# 3      ----  ----        ----        ----      329.59094     13        ----
# 4      ----  ----        ----        ----      117.04022      2        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df41.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df41.reset_index(inplace=True)

# %%
df41.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   2.747  194  179.43025       131146  0.091        131352     Yes  ----
# 1   7.490  230  237.35530       121921  0.145        131378     Yes  ----
# 2  10.814  218  186.56951       165094  0.091        131369     Yes  ----
# 3  12.431  220  186.66486       172327  0.200        131370     Yes  ----
# 4  21.605  222  193.37968       130113  0.073        131371     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      179.43025      5        ----
# 1      ----  ----        ----        ----      237.35530      8        ----
# 2      ----  ----        ----        ----      186.56951      6        ----
# 3      ----  ----        ----        ----      186.66486      6        ----
# 4      ----  ----        ----        ----      193.37968      6        ----
#
# ...

# %%
df39.index
# Out:
# RangeIndex(start=0, stop=136, step=1)

# %%
df40.index
# Out:
# RangeIndex(start=0, stop=42, step=1)

# %%
df41.index
# Out:
# RangeIndex(start=0, stop=160, step=1)

# %%
df39.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df40.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df41.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df39 = df39[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df39.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   3.255       144462  ----  127.72984
# 1   4.418       209425  ----  127.42739
# 2   4.617       153737  ----  127.40511
# 3   6.834       281217  ----  127.31992
# 4   7.488       118041  ----  127.31618

# %%
# Select the required columns for the new DataFrame
df40 = df40[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df40.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0  25.418       124091  ----  100.20396
# 1  25.618       160029  ----  100.13482
# 2  25.890       158533  ----  117.10342
# 3  26.114       191863  ----  329.59094
# 4  26.689       905744  ----  117.04022

# %%
# Select the required columns for the new DataFrame
df41 = df41[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df41.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   2.747       131146  ----  179.43025
# 1   7.490       121921  ----  237.35530
# 2  10.814       165094  ----  186.56951
# 3  12.431       172327  ----  186.66486
# 4  21.605       130113  ----  193.37968

# %%
df39.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       136 non-null    float64
#  1   AREA_COUNTS  136 non-null    int64
#  2   MF           136 non-null    object
#  3   FW           136 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.4+ KB

# %%
df40.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       42 non-null     float64
#  1   AREA_COUNTS  42 non-null     int64
#  2   MF           42 non-null     object
#  3   FW           42 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.4+ KB

# %%
df41.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       160 non-null    float64
#  1   AREA_COUNTS  160 non-null    int64
#  2   MF           160 non-null    object
#  3   FW           160 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.1+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting line plots for each dataframe
plt.plot(df39['FW'], df39['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.plot(df40['FW'], df40['AREA_COUNTS'], label='-ve ABRASION', color='red')
plt.plot(df41['FW'], df41['AREA_COUNTS'], label='-ve ULTRASONIC', color='green')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Line Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Plotting
plt.scatter(df39['FW'], df39['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.scatter(df40['FW'], df40['AREA_COUNTS'], label='-ve ABRASION', color='red')
plt.scatter(df41['FW'], df41['AREA_COUNTS'], label='-ve ULTRASONIC', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df31, df32, df33)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df39_binned = bin_and_sum(df39)
df40_binned = bin_and_sum(df40)
df41_binned = bin_and_sum(df41)

# Plot the binned sums versus 'FW'
plt.plot(df39_binned['FW_bin'], df39_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df40_binned['FW_bin'], df40_binned['AREA_COUNTS'], label='-ve ABRASION', color='red', marker='o')
plt.plot(df41_binned['FW_bin'], df41_binned['AREA_COUNTS'], label='-ve ULTRASONIC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_48348\1605867670.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_48348\1605867670.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %% [markdown]
# ### Plotting Area Counts versus Retention time

# %%
# Plotting
plt.scatter(df39['TR_MIN'], df39['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.scatter(df40['TR_MIN'], df40['AREA_COUNTS'], label='-ve ABRASION', color='red')
plt.scatter(df41['TR_MIN'], df41['AREA_COUNTS'], label='-ve ULTRASONIC', color='green')


# Adding labels and legend
plt.xlabel('TR_MIN')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs TR_MIN')
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting line plots for each dataframe
plt.plot(df39['TR_MIN'], df39['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.plot(df40['TR_MIN'], df40['AREA_COUNTS'], label='-ve ABRASION', color='red')
plt.plot(df41['TR_MIN'], df41['AREA_COUNTS'], label='-ve ULTRASONIC', color='green')

# Adding labels and legend
plt.xlabel('TR_MIN')
plt.ylabel('Area Counts')
plt.title('Combined Line Plot of Area Counts vs TR_MIN')
plt.legend()

# Show plot
plt.show()

# %%
# Check format of the columns df31
df39.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW'], dtype='object')

# %%
# Check format of the columns df32
df40.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW'], dtype='object')

# %%
# Check format of the columns df33
df41.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
df39_binned.head()
# Out:
#       FW_bin  AREA_COUNTS
# 0  100.16091     14530394
# 1  125.16091      1475075
# 2  150.16091       140486
# 3  175.16091      1987027
# 4  200.16091            0

# %%
#Remore certain rows from data set
df39_binned.drop([0,13])
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091      1475075
# 2   150.16091       140486
# 3   175.16091      1987027
# 4   200.16091            0
# 5   225.16091      1345492
# 6   250.16091      1096454
# 7   275.16091            0
# 8   300.16091       431712
# 9   325.16091      2110718
# 10  350.16091      1005505
# 11  375.16091       169923
# 12  400.16091            0
# 14  450.16091       609439
# 15  475.16091            0
# 16  500.16091            0
# 17  525.16091            0
# 18  550.16091            0
# 19  575.16091            0
# 20  600.16091            0
# 21  625.16091      2625237
# 22  650.16091       193304
# 23  675.16091      3312327
# 24  700.16091            0
# 25  725.16091       220867
# 26  750.16091       268628

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df39_binned = bin_and_sum(df39)
df40_binned = bin_and_sum(df40)
df41_binned = bin_and_sum(df41)

# Applying the scaling factors
df39_binned['AREA_COUNTS'] *= 1.000
df40_binned['AREA_COUNTS'] *= 0.000
df41_binned['AREA_COUNTS'] *= 0.000

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df39_binned['FW_bin'], df39_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df40_binned['FW_bin'], df40_binned['AREA_COUNTS'], label='-ve ABRASION', color='red', marker='o')
plt.plot(df41_binned['FW_bin'], df41_binned['AREA_COUNTS'], label='-ve ULTRASONIC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_48348\4123058357.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_48348\4123058357.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
df39_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#New dataframe of binned data
df39_binned = df39_binned.drop([0,13])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[171], line 2
#       1 #New dataframe of binned data
# ----> 2 df39_binned = df39_binned.drop([0,13])
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
#Check if drop() funtioc worked by calling df39.head() again
df39_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
# Plotting the binned and scaled sums versus 'FW'
plt.plot(df39_binned['FW_bin'], df39_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df40_binned['FW_bin'], df40_binned['AREA_COUNTS'], label='-ve ABRASION', color='red', marker='o')
plt.plot(df41_binned['FW_bin'], df41_binned['AREA_COUNTS'], label='-ve ULTRASONIC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-ULTRASONIC-ABRASION POSITIVE
# ### 21st June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df71 = pd.read_excel ('OFR/Amrun_POS.xlsx')
df72 = pd.read_excel ('OFR/Abrasion_POS.xlsx')
df73 = pd.read_excel ('OFR/Ultrasonic_POS.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df71.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0  2002  1.639  462.82278    133688  0.091       906     Yes
# 1  1200  3.160  326.37776    229222  0.091       424     Yes
# 2  2038  5.491  453.78525    109714  0.091       935     Yes
# 3  2037  5.491  449.79079    163774  0.091       935     Yes
# 4   323  5.702  266.28411    114619  0.073       161     Yes
# 5   324  5.702  280.26368    143801  0.073       161     Yes
# 6  2039  5.818  453.78492    102491  0.091       936     Yes
# 7  1201  6.957  326.37808    188914  0.145       425     Yes
# 8   326  7.355  266.28417    167286  0.472       162     Yes
# 9   327  7.355  280.26336    219464  0.472       162     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm) Precursor Ion  \
# 0              ----      ----   ----        ----        ----          ----
# 1              ----      ----   ----        ----        ----          ----
# ...

# %%
df72.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0   428  8.482  291.24302    161936  0.254      3338     Yes
# 1   259  8.536  266.28444    163203  0.273      3278     Yes
# 2   431  8.718  282.94602    100565  0.400      3340     Yes
# 3  1632  9.668  485.35856    403761  0.291      3934     Yes
# 4    16  9.696  156.10187    211972  0.363      3131     Yes
# 5    40  9.715  174.11256    205429  0.254      3145     Yes
# 6   435  9.718  291.24315    646120  0.509      3343     Yes
# 7   784  9.718  313.21216    267157  0.236      3429     Yes
# 8  1681  9.723  508.29994    236210  0.327      3966     Yes
# 9  1730  9.724  536.33087    548443  0.382      3995     Yes
#
#     Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C18 H30 N2 O+H]+     99.26  99.25       -0.07       -0.24      291.24302
# 1      [C18 H35 N+H]+     96.29  96.32        0.21       0.789      266.28444
# ...

# %%
df73.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0     2  1.593  118.08603    377137  0.164      6424     Yes
# 1     4  1.629  102.01271    112533  0.200      6425     Yes
# 2   119  2.284  171.11287    287951  0.472      6522     Yes
# 3     8  2.519  113.05933    355394  0.236      6428     Yes
# 4   125  5.100  174.05480    139944  0.636      6527     Yes
# 5    16  5.444  110.05983    528606  0.581      6434     Yes
# 6    19  5.607  110.05984    346280  0.327      6435     Yes
# 7  1314  6.396  384.18595    311187  0.382      7028     Yes
# 8    68  6.608  156.10166    163195  0.345      6479     Yes
# 9   172  6.863  188.07054    239030  0.472      6566     Yes
#
#     Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0    [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1                ----      ----   ----        ----        ----      102.01271
# ...

# %%
df71.columns = (df71.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df72.columns = (df72.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df73.columns = (df73.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df71.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0  2002   1.639  462.82278       133688  0.091           906     Yes
# 1  1200   3.160  326.37776       229222  0.091           424     Yes
# 2  2038   5.491  453.78525       109714  0.091           935     Yes
# 3  2037   5.491  449.79079       163774  0.091           935     Yes
# 4   323   5.702  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df72.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   428   8.482  291.24302       161936  0.254          3338     Yes
# 1   259   8.536  266.28444       163203  0.273          3278     Yes
# 2   431   8.718  282.94602       100565  0.400          3340     Yes
# 3  1632   9.668  485.35856       403761  0.291          3934     Yes
# 4    16   9.696  156.10187       211972  0.363          3131     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C18 H30 N2 O+H]+     99.26  99.25       -0.07       -0.24      291.24302
# 1      [C18 H35 N+H]+     96.29  96.32        0.21       0.789      266.28444
# 2                ----      ----   ----        ----        ----      282.94602
# 3  [C26 H48 N2 O6+H]+     99.84  89.83        0.05       0.103      485.35856
# 4    [C8 H13 N O2+H]+       100  99.91       -0.04      -0.256      156.10187
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df73.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0    2   1.593  118.08603       377137  0.164          6424     Yes
# 1    4   1.629  102.01271       112533  0.200          6425     Yes
# 2  119   2.284  171.11287       287951  0.472          6522     Yes
# 3    8   2.519  113.05933       355394  0.236          6428     Yes
# 4  125   5.100  174.05480       139944  0.636          6527     Yes
#
#                   MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1               ----      ----   ----        ----        ----      102.01271
# 2  [C8 H14 N2 O2+H]+     99.68  99.55        0.07       0.409      171.11287
# 3      [C6 H8 O2+H]+     54.35  46.56       -0.38      -3.361      113.05933
# 4   [C10 H7 N O2+H]+     55.56  49.62       -0.15      -0.862      174.05480
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df71.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df71.reset_index(inplace=True)

# %%
df71.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.639  2002  462.82278       133688  0.091           906     Yes
# 1   3.160  1200  326.37776       229222  0.091           424     Yes
# 2   5.491  2038  453.78525       109714  0.091           935     Yes
# 3   5.491  2037  449.79079       163774  0.091           935     Yes
# 4   5.702   323  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df72.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df72.reset_index(inplace=True)

# %%
df72.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   8.482   428  291.24302       161936  0.254          3338     Yes
# 1   8.536   259  266.28444       163203  0.273          3278     Yes
# 2   8.718   431  282.94602       100565  0.400          3340     Yes
# 3   9.668  1632  485.35856       403761  0.291          3934     Yes
# 4   9.696    16  156.10187       211972  0.363          3131     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C18 H30 N2 O+H]+     99.26  99.25       -0.07       -0.24      291.24302
# 1      [C18 H35 N+H]+     96.29  96.32        0.21       0.789      266.28444
# 2                ----      ----   ----        ----        ----      282.94602
# 3  [C26 H48 N2 O6+H]+     99.84  89.83        0.05       0.103      485.35856
# 4    [C8 H13 N O2+H]+       100  99.91       -0.04      -0.256      156.10187
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df73.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df73.reset_index(inplace=True)

# %%
df73.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.593    2  118.08603       377137  0.164          6424     Yes
# 1   1.629    4  102.01271       112533  0.200          6425     Yes
# 2   2.284  119  171.11287       287951  0.472          6522     Yes
# 3   2.519    8  113.05933       355394  0.236          6428     Yes
# 4   5.100  125  174.05480       139944  0.636          6527     Yes
#
#                   MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1               ----      ----   ----        ----        ----      102.01271
# 2  [C8 H14 N2 O2+H]+     99.68  99.55        0.07       0.409      171.11287
# 3      [C6 H8 O2+H]+     54.35  46.56       -0.38      -3.361      113.05933
# 4   [C10 H7 N O2+H]+     55.56  49.62       -0.15      -0.862      174.05480
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df71.index
# Out:
# RangeIndex(start=0, stop=2304, step=1)

# %%
df72.index
# Out:
# RangeIndex(start=0, stop=212, step=1)

# %%
df73.index
# Out:
# RangeIndex(start=0, stop=384, step=1)

# %%
df71.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df72.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df73.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df71 = df71[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df71.head()
# Out:
#    TR_MIN  AREA_COUNTS            MF         FW
# 0   1.639       133688          ----  462.82278
# 1   3.160       229222          ----  326.37776
# 2   5.491       109714          ----  453.78525
# 3   5.491       163774          ----  449.79079
# 4   5.702       114619  [C18 H36 N]+  266.28411

# %%
# Select the required columns for the new DataFrame
df72 = df72[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df72.head()
# Out:
#    TR_MIN  AREA_COUNTS                  MF         FW
# 0   8.482       161936   [C18 H30 N2 O+H]+  291.24302
# 1   8.536       163203      [C18 H35 N+H]+  266.28444
# 2   8.718       100565                ----  282.94602
# 3   9.668       403761  [C26 H48 N2 O6+H]+  485.35856
# 4   9.696       211972    [C8 H13 N O2+H]+  156.10187

# %%
# Select the required columns for the new DataFrame
df73 = df73[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df73.head()
# Out:
#    TR_MIN  AREA_COUNTS                 MF         FW
# 0   1.593       377137   [C5 H11 N O2+H]+  118.08603
# 1   1.629       112533               ----  102.01271
# 2   2.284       287951  [C8 H14 N2 O2+H]+  171.11287
# 3   2.519       355394      [C6 H8 O2+H]+  113.05933
# 4   5.100       139944   [C10 H7 N O2+H]+  174.05480

# %%
df71.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       2304 non-null   float64
#  1   AREA_COUNTS  2304 non-null   int64
#  2   MF           2304 non-null   object
#  3   FW           2304 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 72.1+ KB

# %%
df72.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       212 non-null    float64
#  1   AREA_COUNTS  212 non-null    int64
#  2   MF           212 non-null    object
#  3   FW           212 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.8+ KB

# %%
df73.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       384 non-null    float64
#  1   AREA_COUNTS  384 non-null    int64
#  2   MF           384 non-null    object
#  3   FW           384 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 12.1+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting line plots for each dataframe
plt.plot(df71['FW'], df71['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue')
plt.plot(df72['FW'], df72['AREA_COUNTS'], label='+ve ABRASION_POS', color='red')
plt.plot(df73['FW'], df73['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Line Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Plotting
plt.scatter(df71['FW'], df71['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue')
plt.scatter(df72['FW'], df72['AREA_COUNTS'], label='+ve ABRASION_POS', color='red')
plt.scatter(df73['FW'], df73['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df71, df72, df73)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df71_binned = bin_and_sum(df71)
df72_binned = bin_and_sum(df72)
df73_binned = bin_and_sum(df73)

# Plot the binned sums versus 'FW'
plt.plot(df71_binned['FW_bin'], df71_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df72_binned['FW_bin'], df72_binned['AREA_COUNTS'], label='+ve ABRASION_POS', color='red', marker='o')
plt.plot(df73_binned['FW_bin'], df73_binned['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_38716\1403794388.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_38716\1403794388.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %% [markdown]
# ### Plotting Area Counts versus Retention time

# %%
# Plotting
plt.scatter(df71['TR_MIN'], df71['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue')
plt.scatter(df72['TR_MIN'], df72['AREA_COUNTS'], label='+ve ABRASION_POS', color='red')
plt.scatter(df73['TR_MIN'], df73['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green')


# Adding labels and legend
plt.xlabel('TR_MIN')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs TR_MIN')
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting line plots for each dataframe
plt.plot(df71['TR_MIN'], df71['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue')
plt.plot(df72['TR_MIN'], df72['AREA_COUNTS'], label='+ve ABRASION_POS', color='red')
plt.plot(df73['TR_MIN'], df73['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green')

# Adding labels and legend
plt.xlabel('TR_MIN')
plt.ylabel('Area Counts')
plt.title('Combined Line Plot of Area Counts vs TR_MIN')
plt.legend()

# Show plot
plt.show()

# %%
# Check format of the columns df51
df71.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df52
df72.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df53
df73.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df71_binned = bin_and_sum(df71)
df72_binned = bin_and_sum(df72)
df73_binned = bin_and_sum(df73)

# Applying the scaling factors
df71_binned['AREA_COUNTS'] *= 1.000
df72_binned['AREA_COUNTS'] *= 1.305
df73_binned['AREA_COUNTS'] *= 0.832

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df71_binned['FW_bin'], df71_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df72_binned['FW_bin'], df72_binned['AREA_COUNTS'], label='+ve ABRASION_POS', color='red', marker='o')
plt.plot(df73_binned['FW_bin'], df73_binned['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_38716\677785584.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_38716\677785584.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
df71_binned.head()
# Out:
#       FW_bin  AREA_COUNTS
# 0   41.02563    3482428.0
# 1   66.02563   41217646.0
# 2   91.02563   74557855.0
# 3  116.02563   47842495.0
# 4  141.02563   48485987.0

# %%
#RemoVe certain rows from data set
df71_binned = df71_binned.drop([2,8,9,10,11])

# %%
df72_binned.head(27)
# Out:
#        FW_bin   AREA_COUNTS
# 0   142.12266  2.766235e+05
# 1   167.12266  3.730044e+06
# 2   192.12266  5.444329e+05
# 3   217.12266  2.104617e+06
# 4   242.12266  1.883773e+07
# 5   267.12266  4.409675e+07
# 6   292.12266  4.217577e+07
# 7   317.12266  4.099472e+07
# 8   342.12266  1.388145e+07
# 9   367.12266  3.867583e+06
# 10  392.12266  5.340921e+05
# 11  417.12266  5.049100e+06
# 12  442.12266  2.742571e+06
# 13  467.12266  2.637140e+06
# 14  492.12266  2.014027e+06
# 15  517.12266  2.138764e+06
# 16  542.12266  1.704860e+06
# 17  567.12266  7.325970e+05
# 18  592.12266  5.185701e+06
# 19  617.12266  5.508032e+06
# 20  642.12266  1.450457e+06
# 21  667.12266  2.314979e+05
# 22  692.12266  7.678568e+05

# %%
#New dataframe of binned data
#df72_binned = df72_binned.drop([0,13])

# %%
df73_binned.head(27)
# Out:
#        FW_bin   AREA_COUNTS
# 0   102.01271  1.540614e+06
# 1   127.01271  1.114607e+06
# 2   152.01271  1.414761e+06
# 3   177.01271  1.097912e+06
# 4   202.01271  4.551298e+05
# 5   227.01271  1.188158e+06
# 6   252.01271  4.137936e+06
# 7   277.01271  2.017614e+07
# 8   302.01271  3.089837e+07
# 9   327.01271  1.855122e+07
# 10  352.01271  1.864475e+07
# 11  377.01271  1.394488e+07
# 12  402.01271  6.399428e+06
# 13  427.01271  1.039052e+07
# 14  452.01271  1.084803e+07
# 15  477.01271  1.253938e+07
# 16  502.01271  4.905279e+06
# 17  527.01271  9.185026e+06
# 18  552.01271  6.997859e+06
# 19  577.01271  1.009559e+07
# 20  602.01271  4.109779e+06
# 21  627.01271  4.738593e+06
# 22  652.01271  7.247439e+06
# 23  677.01271  2.550575e+06
# 24  702.01271  1.356604e+07
# 25  727.01271  1.127751e+07
# 26  752.01271  1.685083e+05

# %%
# Plotting the binned and scaled sums versus 'FW'
plt.plot(df71_binned['FW_bin'], df71_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df72_binned['FW_bin'], df72_binned['AREA_COUNTS'], label='+ve ABRASION_POS', color='red', marker='o')
plt.plot(df73_binned['FW_bin'], df73_binned['AREA_COUNTS'], label='+ve ULTRASONIC_POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

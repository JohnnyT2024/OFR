# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-AMRUN 350oC-MICROWAVE (-2.36+212um)
# ### 13th June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df31 = pd.read_excel ('OFR/Amrun.xlsx')
df32 = pd.read_excel ('OFR/Amrun350.xlsx')
df33 = pd.read_excel ('OFR/Microwave2pt36and212.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df31.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  145   3.255  127.72984    144462  0.109    129518     Yes
# 1  156   4.418  127.42739    209425  0.145    129527     Yes
# 2  157   4.617  127.40511    153737  0.055    129528     Yes
# 3  171   6.834  127.31992    281217  0.254    129540     Yes
# 4  175   7.488  127.31618    118041  0.055    129544     Yes
# 5  182   8.505  127.45210    235721  0.309    129549     Yes
# 6  184   8.723  127.60602    114039  0.145    129550     Yes
# 7  257  11.122  165.80799    140486  0.127    129616     Yes
# 8  259  11.177  186.99339    963197  0.200    129617     Yes
# 9  262  11.304  186.91464    272184  0.055    129619     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      127.72984
# 1              ----      ----  ----        ----        ----      127.42739
# ...

# %%
df32.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  148   1.565  127.65521    140180  0.073    125397     Yes
# 1  156   2.056  127.56700    138387  0.182    125403     Yes
# 2  293   5.710  223.67298    163853  0.200    125517     Yes
# 3  268  11.032  187.22693    166809  0.109    125500     Yes
# 4  269  11.068  187.16461    399289  0.309    125501     Yes
# 5  271  11.086  187.11659    297091  0.436    125502     Yes
# 6  274  11.159  187.09705    251641  0.254    125503     Yes
# 7  277  11.795  186.65726    191342  0.091    125506     Yes
# 8  280  11.976  186.64351    416551  0.218    125508     Yes
# 9  283  12.013  187.01855    282628  0.436    125509     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----   ----        ----        ----      127.65521
# 1              ----      ----   ----        ----        ----      127.56700
# ...

# %%
df33.head(10)
# Out:
#      #      RT        m/z  Response  Width  RT Group Predict  \
# 0  142   1.675  179.73394    217922  0.164    126299     Yes
# 1  169   1.876  198.66387    114066  0.327    126321     Yes
# 2  151   3.674  179.55506    146842  0.436    126306     Yes
# 3  154   3.983  179.61921    163796  0.491    126308     Yes
# 4  180  10.668  186.75368    150026  0.182    126331     Yes
# 5   10  25.436  100.15641    121405  0.236    126192     Yes
# 6   24  27.580  100.32714    504164  0.182    126205     Yes
# 7   26  27.634  100.33682    247499  0.164    126206     Yes
# 8   32  28.016  117.37791    368694  0.309    126210     Yes
# 9   35  28.343  100.32495    157155  0.073    126212     Yes
#
#   Predicted Formula Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0              ----      ----  ----        ----        ----      179.73394
# 1              ----      ----  ----        ----        ----      198.66387
# ...

# %%
df31.columns = (df31.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df32.columns = (df31.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df33.columns = (df31.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df31.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  145   3.255  127.72984       144462  0.109        129518     Yes  ----
# 1  156   4.418  127.42739       209425  0.145        129527     Yes  ----
# 2  157   4.617  127.40511       153737  0.055        129528     Yes  ----
# 3  171   6.834  127.31992       281217  0.254        129540     Yes  ----
# 4  175   7.488  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
df32.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  148   1.565  127.65521       140180  0.073        125397     Yes  ----
# 1  156   2.056  127.56700       138387  0.182        125403     Yes  ----
# 2  293   5.710  223.67298       163853  0.200        125517     Yes  ----
# 3  268  11.032  187.22693       166809  0.109        125500     Yes  ----
# 4  269  11.068  187.16461       399289  0.309        125501     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.65521      3        ----
# 1      ----  ----        ----        ----      127.56700      3        ----
# 2      ----  ----        ----        ----      223.67298      8        ----
# 3      ----  ----        ----        ----      187.22693      6        ----
# 4      ----  ----        ----        ----      187.16461      6        ----
#
# ...

# %%
df33.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  142   1.675  179.73394       217922  0.164        126299     Yes  ----
# 1  169   1.876  198.66387       114066  0.327        126321     Yes  ----
# 2  151   3.674  179.55506       146842  0.436        126306     Yes  ----
# 3  154   3.983  179.61921       163796  0.491        126308     Yes  ----
# 4  180  10.668  186.75368       150026  0.182        126331     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      179.73394      5        ----
# 1      ----  ----        ----        ----      198.66387      6        ----
# 2      ----  ----        ----        ----      179.55506      5        ----
# 3      ----  ----        ----        ----      179.61921      5        ----
# 4      ----  ----        ----        ----      186.75368      6        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df31.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df31.reset_index(inplace=True)

# %%
df31.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   3.255  145  127.72984       144462  0.109        129518     Yes  ----
# 1   4.418  156  127.42739       209425  0.145        129527     Yes  ----
# 2   4.617  157  127.40511       153737  0.055        129528     Yes  ----
# 3   6.834  171  127.31992       281217  0.254        129540     Yes  ----
# 4   7.488  175  127.31618       118041  0.055        129544     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.72984      3        ----
# 1      ----  ----        ----        ----      127.42739      3        ----
# 2      ----  ----        ----        ----      127.40511      3        ----
# 3      ----  ----        ----        ----      127.31992      3        ----
# 4      ----  ----        ----        ----      127.31618      3        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df32.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df32.reset_index(inplace=True)

# %%
df32.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   1.565  148  127.65521       140180  0.073        125397     Yes  ----
# 1   2.056  156  127.56700       138387  0.182        125403     Yes  ----
# 2   5.710  293  223.67298       163853  0.200        125517     Yes  ----
# 3  11.032  268  187.22693       166809  0.109        125500     Yes  ----
# 4  11.068  269  187.16461       399289  0.309        125501     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      127.65521      3        ----
# 1      ----  ----        ----        ----      127.56700      3        ----
# 2      ----  ----        ----        ----      223.67298      8        ----
# 3      ----  ----        ----        ----      187.22693      6        ----
# 4      ----  ----        ----        ----      187.16461      6        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df33.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df33.reset_index(inplace=True)

# %%
df33.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   1.675  142  179.73394       217922  0.164        126299     Yes  ----
# 1   1.876  169  198.66387       114066  0.327        126321     Yes  ----
# 2   3.674  151  179.55506       146842  0.436        126306     Yes  ----
# 3   3.983  154  179.61921       163796  0.491        126308     Yes  ----
# 4  10.668  180  186.75368       150026  0.182        126331     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm)  Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----      179.73394      5        ----
# 1      ----  ----        ----        ----      198.66387      6        ----
# 2      ----  ----        ----        ----      179.55506      5        ----
# 3      ----  ----        ----        ----      179.61921      5        ----
# 4      ----  ----        ----        ----      186.75368      6        ----
#
# ...

# %%
df31.index
# Out:
# RangeIndex(start=0, stop=136, step=1)

# %%
df32.index
# Out:
# RangeIndex(start=0, stop=172, step=1)

# %%
df33.index
# Out:
# RangeIndex(start=0, stop=145, step=1)

# %%
df31.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df32.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df33.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df31 = df31[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df31.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   3.255       144462  ----  127.72984
# 1   4.418       209425  ----  127.42739
# 2   4.617       153737  ----  127.40511
# 3   6.834       281217  ----  127.31992
# 4   7.488       118041  ----  127.31618

# %%
# Select the required columns for the new DataFrame
df32 = df32[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df32.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   1.565       140180  ----  127.65521
# 1   2.056       138387  ----  127.56700
# 2   5.710       163853  ----  223.67298
# 3  11.032       166809  ----  187.22693
# 4  11.068       399289  ----  187.16461

# %%
# Select the required columns for the new DataFrame
df33 = df33[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df33.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   1.675       217922  ----  179.73394
# 1   1.876       114066  ----  198.66387
# 2   3.674       146842  ----  179.55506
# 3   3.983       163796  ----  179.61921
# 4  10.668       150026  ----  186.75368

# %%
df31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       136 non-null    float64
#  1   AREA_COUNTS  136 non-null    int64
#  2   MF           136 non-null    object
#  3   FW           136 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.4+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting
plt.scatter(df31['FW'], df31['AREA_COUNTS'], label='-ve AMRUN', color='blue')
plt.scatter(df32['FW'], df32['AREA_COUNTS'], label='-ve AMRUN 350oC', color='red')
plt.scatter(df33['FW'], df33['AREA_COUNTS'], label='-ve MICROWAVE', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df31, df32, df33)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df31_binned = bin_and_sum(df31)
df32_binned = bin_and_sum(df32)
df33_binned = bin_and_sum(df33)

# Plot the binned sums versus 'FW'
plt.plot(df31_binned['FW_bin'], df31_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df32_binned['FW_bin'], df32_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='red', marker='o')
plt.plot(df33_binned['FW_bin'], df33_binned['AREA_COUNTS'], label='-ve MICROWAVE', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_52420\2583811899.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_52420\2583811899.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
# Check format of the columns df31
df31.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df32
df32.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df33
df33.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 50 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df31_binned = bin_and_sum(df31)
df32_binned = bin_and_sum(df32)
df33_binned = bin_and_sum(df33)

# Applying the scaling factors
df31_binned['AREA_COUNTS'] *= 1.000
df32_binned['AREA_COUNTS'] *= 0.4995
df33_binned['AREA_COUNTS'] *= 0.0518

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df31_binned['FW_bin'], df31_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df32_binned['FW_bin'], df32_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='red', marker='o')
plt.plot(df33_binned['FW_bin'], df33_binned['AREA_COUNTS'], label='-ve MICROWAVE', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_52420\2142227109.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_52420\2142227109.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
#Check the summary of binned data for df31
df31_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 0   100.16091   14530394.0
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 13  425.16091   13550226.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check the summary of binned data for df32
df32_binned.head(26)
# Out:
#        FW_bin   AREA_COUNTS
# 0   100.00145  8.529380e+06
# 1   125.00145  3.937009e+05
# 2   150.00145  0.000000e+00
# 3   175.00145  1.085465e+06
# 4   200.00145  8.184457e+04
# 5   225.00145  5.658006e+05
# 6   250.00145  0.000000e+00
# 7   275.00145  1.680852e+05
# 8   300.00145  1.179127e+06
# 9   325.00145  1.939391e+06
# 10  350.00145  6.082227e+05
# 11  375.00145  3.609632e+05
# 12  400.00145  7.389253e+04
# 13  425.00145  9.016044e+06
# 14  450.00145  5.658176e+05
# 15  475.00145  2.424853e+05
# 16  500.00145  0.000000e+00
# 17  525.00145  0.000000e+00
# 18  550.00145  0.000000e+00
# 19  575.00145  0.000000e+00
# 20  600.00145  0.000000e+00
# 21  625.00145  2.272465e+06
# 22  650.00145  0.000000e+00
# 23  675.00145  2.354058e+06
# 24  700.00145  0.000000e+00
# 25  725.00145  1.347599e+06

# %%
#Check the summary of binned data for df33
df33_binned.head(26)
# Out:
#        FW_bin   AREA_COUNTS
# 0   100.12336  4.671321e+05
# 1   125.12336  0.000000e+00
# 2   150.12336  0.000000e+00
# 3   175.12336  4.105937e+04
# 4   200.12336  0.000000e+00
# 5   225.12336  0.000000e+00
# 6   250.12336  0.000000e+00
# 7   275.12336  5.223414e+04
# 8   300.12336  0.000000e+00
# 9   325.12336  9.280923e+04
# 10  350.12336  6.020300e+03
# 11  375.12336  2.837682e+04
# 12  400.12336  0.000000e+00
# 13  425.12336  1.506782e+06
# 14  450.12336  8.380354e+04
# 15  475.12336  0.000000e+00
# 16  500.12336  0.000000e+00
# 17  525.12336  0.000000e+00
# 18  550.12336  0.000000e+00
# 19  575.12336  0.000000e+00
# 20  600.12336  0.000000e+00
# 21  625.12336  4.685373e+05
# 22  650.12336  0.000000e+00
# 23  675.12336  4.386276e+05
# 24  700.12336  0.000000e+00
# 25  725.12336  3.909898e+05

# %%
#New dataframe of df31 binned data by dropping row [0] and row [13] 
df31_binned = df31_binned.drop([0,13])

# %%
#New dataframe of df32 binned data by dropping row [0] and row [13] 
df32_binned = df32_binned.drop([0,13])

# %%
#New dataframe of df33 binned data by dropping row [0] and row [13] 
df33_binned = df33_binned.drop([0,13])

# %%
#Check if drop() function worked by calling df31.head() again
df31_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.16091    1475075.0
# 2   150.16091     140486.0
# 3   175.16091    1987027.0
# 4   200.16091          0.0
# 5   225.16091    1345492.0
# 6   250.16091    1096454.0
# 7   275.16091          0.0
# 8   300.16091     431712.0
# 9   325.16091    2110718.0
# 10  350.16091    1005505.0
# 11  375.16091     169923.0
# 12  400.16091          0.0
# 14  450.16091     609439.0
# 15  475.16091          0.0
# 16  500.16091          0.0
# 17  525.16091          0.0
# 18  550.16091          0.0
# 19  575.16091          0.0
# 20  600.16091          0.0
# 21  625.16091    2625237.0
# 22  650.16091     193304.0
# 23  675.16091    3312327.0
# 24  700.16091          0.0
# 25  725.16091     220867.0
# 26  750.16091     268628.0

# %%
#Check if drop() function worked by calling df32.head() again
df32_binned.head(25)
# Out:
#        FW_bin   AREA_COUNTS
# 1   125.00145  3.937009e+05
# 2   150.00145  0.000000e+00
# 3   175.00145  1.085465e+06
# 4   200.00145  8.184457e+04
# 5   225.00145  5.658006e+05
# 6   250.00145  0.000000e+00
# 7   275.00145  1.680852e+05
# 8   300.00145  1.179127e+06
# 9   325.00145  1.939391e+06
# 10  350.00145  6.082227e+05
# 11  375.00145  3.609632e+05
# 12  400.00145  7.389253e+04
# 14  450.00145  5.658176e+05
# 15  475.00145  2.424853e+05
# 16  500.00145  0.000000e+00
# 17  525.00145  0.000000e+00
# 18  550.00145  0.000000e+00
# 19  575.00145  0.000000e+00
# 20  600.00145  0.000000e+00
# 21  625.00145  2.272465e+06
# 22  650.00145  0.000000e+00
# 23  675.00145  2.354058e+06
# 24  700.00145  0.000000e+00
# 25  725.00145  1.347599e+06

# %%
#Check if drop() function worked by calling df33.head() again
df33_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 1   125.12336       0.0000
# 2   150.12336       0.0000
# 3   175.12336   41059.3736
# 4   200.12336       0.0000
# 5   225.12336       0.0000
# 6   250.12336       0.0000
# 7   275.12336   52234.1358
# 8   300.12336       0.0000
# 9   325.12336   92809.2312
# 10  350.12336    6020.2996
# 11  375.12336   28376.8170
# 12  400.12336       0.0000
# 14  450.12336   83803.5422
# 15  475.12336       0.0000
# 16  500.12336       0.0000
# 17  525.12336       0.0000
# 18  550.12336       0.0000
# 19  575.12336       0.0000
# 20  600.12336       0.0000
# 21  625.12336  468537.3196
# 22  650.12336       0.0000
# 23  675.12336  438627.5852
# 24  700.12336       0.0000
# 25  725.12336  390989.7670
# 26  750.12336   19524.5078

# %%
# Plotting the binned and scaled sums versus 'FW' of adusjted graphs
plt.plot(df31_binned['FW_bin'], df31_binned['AREA_COUNTS'], label='-ve AMRUN', color='blue', marker='o')
plt.plot(df32_binned['FW_bin'], df32_binned['AREA_COUNTS'], label='-ve AMRUN 350oC', color='red', marker='o')
plt.plot(df33_binned['FW_bin'], df33_binned['AREA_COUNTS'], label='-ve MICROWAVE', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-AMRUN275-AMRUN350 POSITIVE
# ### 21st June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df68 = pd.read_excel ('OFR/Amrun_POS.xlsx')
df69 = pd.read_excel ('OFR/Amrun275_POS.xlsx')
df70 = pd.read_excel ('OFR/Amrun350_POS.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df68.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0  2002  1.639  462.82278    133688  0.091       906     Yes
# 1  1200  3.160  326.37776    229222  0.091       424     Yes
# 2  2038  5.491  453.78525    109714  0.091       935     Yes
# 3  2037  5.491  449.79079    163774  0.091       935     Yes
# 4   323  5.702  266.28411    114619  0.073       161     Yes
# 5   324  5.702  280.26368    143801  0.073       161     Yes
# 6  2039  5.818  453.78492    102491  0.091       936     Yes
# 7  1201  6.957  326.37808    188914  0.145       425     Yes
# 8   326  7.355  266.28417    167286  0.472       162     Yes
# 9   327  7.355  280.26336    219464  0.472       162     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm) Precursor Ion  \
# 0              ----      ----   ----        ----        ----          ----
# 1              ----      ----   ----        ----        ----          ----
# ...

# %%
df69.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0  1084  1.689  326.37839    368183  0.073      1508     Yes
# 1  1878  3.056  449.79069    130494  0.036      2027     Yes
# 2  1879  4.546  490.81701    103406  0.127      2028     Yes
# 3  1085  7.684  326.37796    127639  0.091      1509     Yes
# 4  1880  7.852  449.79036    171780  0.236      2029     Yes
# 5  1881  7.907  453.78540    162702  0.236      2030     Yes
# 6   275  8.173  280.26361    243427  0.273      1233     Yes
# 7   274  8.173  266.28395    185593  0.164      1233     Yes
# 8   276  8.264  262.25287    102335  0.345      1234     Yes
# 9   277  8.264  274.27393    122492  0.345      1234     Yes
#
#    Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm) Precursor Ion  \
# 0               ----      ----   ----        ----        ----          ----
# 1               ----      ----   ----        ----        ----          ----
# ...

# %%
df70.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0   917  1.689  326.37788    427237  0.091      2580     Yes
# 1   927  9.700  327.22774    292936  0.200      2583     Yes
# 2  1137  9.701  341.24362    368472  0.363      2698     Yes
# 3  1293  9.702  395.21593    119459  0.236      2810     Yes
# 4  1540  9.705  536.33086    448233  0.218      2992     Yes
# 5  1551  9.706  550.34690    307939  0.291      3000     Yes
# 6  1295  9.738  387.24901    174162  0.327      2811     Yes
# 7    19  9.750  156.10185    214890  0.382      2216     Yes
# 8   121  9.752  216.12283    110057  0.382      2265     Yes
# 9  1140  9.755  342.24514    123826  0.254      2699     Yes
#
#     Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# ...

# %%
df68.columns = (df68.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df69.columns = (df69.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df70.columns = (df70.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df68.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0  2002   1.639  462.82278       133688  0.091           906     Yes
# 1  1200   3.160  326.37776       229222  0.091           424     Yes
# 2  2038   5.491  453.78525       109714  0.091           935     Yes
# 3  2037   5.491  449.79079       163774  0.091           935     Yes
# 4   323   5.702  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df69.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0  1084   1.689  326.37839       368183  0.073          1508     Yes  ----
# 1  1878   3.056  449.79069       130494  0.036          2027     Yes  ----
# 2  1879   4.546  490.81701       103406  0.127          2028     Yes  ----
# 3  1085   7.684  326.37796       127639  0.091          1509     Yes  ----
# 4  1880   7.852  449.79036       171780  0.236          2029     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----          ----     13        ----
# 1      ----  ----        ----        ----          ----     23        ----
# 2      ----  ----        ----        ----          ----     23        ----
# 3      ----  ----        ----        ----          ----     13        ----
# 4      ----  ----        ----        ----          ----     23        ----
#
# ...

# %%
df70.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   917   1.689  326.37788       427237  0.091          2580     Yes
# 1   927   9.700  327.22774       292936  0.200          2583     Yes
# 2  1137   9.701  341.24362       368472  0.363          2698     Yes
# 3  1293   9.702  395.21593       119459  0.236          2810     Yes
# 4  1540   9.705  536.33086       448233  0.218          2992     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# 2  [C18 H32 N2 O4+H]+     55.48  49.77        0.14        0.41      341.24362
# 3    [C18 H29 N5 O5]+     83.35  84.56       -0.39      -0.987      395.21593
# 4      [C23 H36 N16]+     55.63  49.63        0.52        0.97      536.33086
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df68.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df68.reset_index(inplace=True)

# %%
df68.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.639  2002  462.82278       133688  0.091           906     Yes
# 1   3.160  1200  326.37776       229222  0.091           424     Yes
# 2   5.491  2038  453.78525       109714  0.091           935     Yes
# 3   5.491  2037  449.79079       163774  0.091           935     Yes
# 4   5.702   323  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df69.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df69.reset_index(inplace=True)

# %%
df69.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict    MF  \
# 0   1.689  1084  326.37839       368183  0.073          1508     Yes  ----
# 1   3.056  1878  449.79069       130494  0.036          2027     Yes  ----
# 2   4.546  1879  490.81701       103406  0.127          2028     Yes  ----
# 3   7.684  1085  326.37796       127639  0.091          1509     Yes  ----
# 4   7.852  1880  449.79036       171780  0.236          2029     Yes  ----
#
#   Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event Target Name  \
# 0      ----  ----        ----        ----          ----     13        ----
# 1      ----  ----        ----        ----          ----     23        ----
# 2      ----  ----        ----        ----          ----     23        ----
# 3      ----  ----        ----        ----          ----     13        ----
# 4      ----  ----        ----        ----          ----     23        ----
#
# ...

# %%
# Set TR_MIN as index for dataframe

df70.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df70.reset_index(inplace=True)

# %%
df70.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.689   917  326.37788       427237  0.091          2580     Yes
# 1   9.700   927  327.22774       292936  0.200          2583     Yes
# 2   9.701  1137  341.24362       368472  0.363          2698     Yes
# 3   9.702  1293  395.21593       119459  0.236          2810     Yes
# 4   9.705  1540  536.33086       448233  0.218          2992     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# 2  [C18 H32 N2 O4+H]+     55.48  49.77        0.14        0.41      341.24362
# 3    [C18 H29 N5 O5]+     83.35  84.56       -0.39      -0.987      395.21593
# 4      [C23 H36 N16]+     55.63  49.63        0.52        0.97      536.33086
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df68.index
# Out:
# RangeIndex(start=0, stop=2304, step=1)

# %%
df69.index
# Out:
# RangeIndex(start=0, stop=2209, step=1)

# %%
df70.index
# Out:
# RangeIndex(start=0, stop=179, step=1)

# %%
df68.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df69.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df70.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df68 = df68[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df68.head()
# Out:
#    TR_MIN  AREA_COUNTS            MF         FW
# 0   1.639       133688          ----  462.82278
# 1   3.160       229222          ----  326.37776
# 2   5.491       109714          ----  453.78525
# 3   5.491       163774          ----  449.79079
# 4   5.702       114619  [C18 H36 N]+  266.28411

# %%
# Select the required columns for the new DataFrame
df69 = df69[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df69.head()
# Out:
#    TR_MIN  AREA_COUNTS    MF         FW
# 0   1.689       368183  ----  326.37839
# 1   3.056       130494  ----  449.79069
# 2   4.546       103406  ----  490.81701
# 3   7.684       127639  ----  326.37796
# 4   7.852       171780  ----  449.79036

# %%
# Select the required columns for the new DataFrame
df70 = df70[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df70.head()
# Out:
#    TR_MIN  AREA_COUNTS                  MF         FW
# 0   1.689       427237      [C22 H47 N+H]+  326.37788
# 1   9.700       292936  [C17 H30 N2 O4+H]+  327.22774
# 2   9.701       368472  [C18 H32 N2 O4+H]+  341.24362
# 3   9.702       119459    [C18 H29 N5 O5]+  395.21593
# 4   9.705       448233      [C23 H36 N16]+  536.33086

# %%
df68.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       2304 non-null   float64
#  1   AREA_COUNTS  2304 non-null   int64
#  2   MF           2304 non-null   object
#  3   FW           2304 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 72.1+ KB

# %%
df69.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       2209 non-null   float64
#  1   AREA_COUNTS  2209 non-null   int64
#  2   MF           2209 non-null   object
#  3   FW           2209 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 69.2+ KB

# %%
df70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       179 non-null    float64
#  1   AREA_COUNTS  179 non-null    int64
#  2   MF           179 non-null    object
#  3   FW           179 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.7+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting
plt.scatter(df68['FW'], df68['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue')
plt.scatter(df69['FW'], df69['AREA_COUNTS'], label='+ve AMRUN 275oC_POS', color='red')
plt.scatter(df70['FW'], df70['AREA_COUNTS'], label='+ve AMRUN 350oC_POS', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df68, df69, df70)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df68_binned = bin_and_sum(df68)
df69_binned = bin_and_sum(df69)
df70_binned = bin_and_sum(df70)

# Plot the binned sums versus 'FW'
plt.plot(df68_binned['FW_bin'], df68_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df69_binned['FW_bin'], df69_binned['AREA_COUNTS'], label='+ve AMRUN 275oC_POS', color='red', marker='o')
plt.plot(df70_binned['FW_bin'], df70_binned['AREA_COUNTS'], label='+ve AMRUN 350oC', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_34848\1861219259.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_34848\1861219259.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
# Check format of the columns df31
df68.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df32
df69.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df33
df70.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df68_binned = bin_and_sum(df68)
df69_binned = bin_and_sum(df69)
df70_binned = bin_and_sum(df70)

# Applying the scaling factors
df68_binned['AREA_COUNTS'] *= 1.000
df69_binned['AREA_COUNTS'] *= 0.683
df70_binned['AREA_COUNTS'] *= 0.133

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df68_binned['FW_bin'], df68_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df69_binned['FW_bin'], df69_binned['AREA_COUNTS'], label='+ve AMRUN 275oC_POS', color='red', marker='o')
plt.plot(df70_binned['FW_bin'], df70_binned['AREA_COUNTS'], label='+ve AMRUN 350oC_POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_34848\34568510.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_34848\34568510.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
#Check the summary of binned data for df68
df68_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 0    41.02563    3482428.0
# 1    66.02563   41217646.0
# 2    91.02563   74557855.0
# 3   116.02563   47842495.0
# 4   141.02563   48485987.0
# 5   166.02563   35349165.0
# 6   191.02563   14151970.0
# 7   216.02563   21650856.0
# 8   241.02563   81826610.0
# 9   266.02563  109370912.0
# 10  291.02563   82911893.0
# 11  316.02563  113738192.0
# 12  341.02563   39774398.0
# 13  366.02563   23676489.0
# 14  391.02563    6873903.0
# 15  416.02563   10782516.0
# 16  441.02563    9772563.0
# 17  466.02563   11076949.0
# 18  491.02563   12145166.0
# 19  516.02563    5285609.0
# 20  541.02563    4956488.0
# 21  566.02563    3089044.0
# 22  591.02563    6020777.0
# 23  616.02563    5471390.0
# 24  641.02563    4481863.0
# 25  666.02563    1410676.0
# 26  691.02563    2997172.0

# %%
#Check the summary of binned data for df69
df69_binned.head(27)
# Out:
#        FW_bin   AREA_COUNTS
# 0    42.03346  1.922084e+06
# 1    67.03346  3.406507e+07
# 2    92.03346  3.941345e+07
# 3   117.03346  2.704957e+07
# 4   142.03346  3.030154e+07
# 5   167.03346  2.447247e+07
# 6   192.03346  1.202222e+07
# 7   217.03346  2.017384e+07
# 8   242.03346  4.906272e+07
# 9   267.03346  7.788472e+07
# 10  292.03346  5.589663e+07
# 11  317.03346  6.084539e+07
# 12  342.03346  2.925345e+07
# 13  367.03346  9.739893e+06
# 14  392.03346  3.984403e+06
# 15  417.03346  9.835317e+06
# 16  442.03346  6.830670e+06
# 17  467.03346  9.863220e+06
# 18  492.03346  4.245822e+06
# 19  517.03346  3.807616e+06
# 20  542.03346  6.657234e+06
# 21  567.03346  2.659663e+06
# 22  592.03346  7.382130e+06
# 23  617.03346  5.200055e+06
# 24  642.03346  4.092324e+06
# 25  667.03346  3.088191e+06
# 26  692.03346  5.029016e+06

# %%
#Check the summary of binned data for df70
df70_binned.head(28)
# Out:
#        FW_bin  AREA_COUNTS
# 0   156.10185   177296.448
# 1   181.10185   124985.952
# 2   206.10185   104354.327
# 3   231.10185   125623.554
# 4   256.10185  5515109.537
# 5   281.10185  4329615.101
# 6   306.10185  4258291.590
# 7   331.10185  1274035.196
# 8   356.10185   542225.439
# 9   381.10185   536366.257
# 10  406.10185   125018.537
# 11  431.10185   151099.571
# 12  456.10185   248404.632
# 13  481.10185   283647.238
# 14  506.10185    32547.228
# 15  531.10185   100570.876
# 16  556.10185   184289.455
# 17  581.10185   381246.096
# 18  606.10185   107136.953
# 19  631.10185    94811.577
# 20  656.10185   115356.486
# 21  681.10185    25882.864
# 22  706.10185    90918.401

# %%
#New dataframe of df68 binned data 
df68_binned = df68_binned.drop([2,8,9,10,11])

# %%
#New dataframe of df 69 binned data 
df69_binned = df69_binned.drop([2,8,9,10,11])

# %%
#New dataframe of df70 binned data
#df70_binned = df70_binned.drop([0,13])

# %%
#Check if drop() funtioc worked by calling df68.head() again
df68_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 0    41.02563    3482428.0
# 1    66.02563   41217646.0
# 3   116.02563   47842495.0
# 4   141.02563   48485987.0
# 5   166.02563   35349165.0
# 6   191.02563   14151970.0
# 7   216.02563   21650856.0
# 12  341.02563   39774398.0
# 13  366.02563   23676489.0
# 14  391.02563    6873903.0
# 15  416.02563   10782516.0
# 16  441.02563    9772563.0
# 17  466.02563   11076949.0
# 18  491.02563   12145166.0
# 19  516.02563    5285609.0
# 20  541.02563    4956488.0
# 21  566.02563    3089044.0
# 22  591.02563    6020777.0
# 23  616.02563    5471390.0
# 24  641.02563    4481863.0
# 25  666.02563    1410676.0
# 26  691.02563    2997172.0
# 27  716.02563     616060.0
# 28  741.02563     128319.0

# %%
#Check if drop() function worked by calling df69.head() again
df69_binned.head(25)
# Out:
#        FW_bin   AREA_COUNTS
# 0    42.03346  1.922084e+06
# 1    67.03346  3.406507e+07
# 3   117.03346  2.704957e+07
# 4   142.03346  3.030154e+07
# 5   167.03346  2.447247e+07
# 6   192.03346  1.202222e+07
# 7   217.03346  2.017384e+07
# 12  342.03346  2.925345e+07
# 13  367.03346  9.739893e+06
# 14  392.03346  3.984403e+06
# 15  417.03346  9.835317e+06
# 16  442.03346  6.830670e+06
# 17  467.03346  9.863220e+06
# 18  492.03346  4.245822e+06
# 19  517.03346  3.807616e+06
# 20  542.03346  6.657234e+06
# 21  567.03346  2.659663e+06
# 22  592.03346  7.382130e+06
# 23  617.03346  5.200055e+06
# 24  642.03346  4.092324e+06
# 25  667.03346  3.088191e+06
# 26  692.03346  5.029016e+06
# 27  717.03346  9.545246e+05
# 28  742.03346  6.860072e+05

# %%
#Check if drop() function worked by calling df70.head() again
df70_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 0   156.10185   177296.448
# 1   181.10185   124985.952
# 2   206.10185   104354.327
# 3   231.10185   125623.554
# 4   256.10185  5515109.537
# 5   281.10185  4329615.101
# 6   306.10185  4258291.590
# 7   331.10185  1274035.196
# 8   356.10185   542225.439
# 9   381.10185   536366.257
# 10  406.10185   125018.537
# 11  431.10185   151099.571
# 12  456.10185   248404.632
# 13  481.10185   283647.238
# 14  506.10185    32547.228
# 15  531.10185   100570.876
# 16  556.10185   184289.455
# 17  581.10185   381246.096
# 18  606.10185   107136.953
# 19  631.10185    94811.577
# 20  656.10185   115356.486
# 21  681.10185    25882.864
# 22  706.10185    90918.401

# %%
# Plotting the binned and scaled sums versus 'FW'
plt.plot(df68_binned['FW_bin'], df68_binned['AREA_COUNTS'], label='+ve AMRUN_POS', color='blue', marker='o')
plt.plot(df69_binned['FW_bin'], df69_binned['AREA_COUNTS'], label='+ve AMRUN 275oC_POS', color='red', marker='o')
plt.plot(df70_binned['FW_bin'], df70_binned['AREA_COUNTS'], label='+ve AMRUN 350oC_POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()

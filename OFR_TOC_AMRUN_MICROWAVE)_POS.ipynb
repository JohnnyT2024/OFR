# %% [markdown]
# # Jonathan Thabano¶
# ## LC-MS Bayer Liquor OFR TOC Negative Mode Dataset AMRUN-AMRUN 350oC-MICROWAVE (-2.36+212um) POSITIVE
# ### 21st June 2024

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df54 = pd.read_excel ('OFR/Amrun_POS.xlsx')
df55 = pd.read_excel ('OFR/Amrun350_POS.xlsx')
df56 = pd.read_excel ('OFR/MICROWAVE2pt36minus212UM_POS.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
df54.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0  2002  1.639  462.82278    133688  0.091       906     Yes
# 1  1200  3.160  326.37776    229222  0.091       424     Yes
# 2  2038  5.491  453.78525    109714  0.091       935     Yes
# 3  2037  5.491  449.79079    163774  0.091       935     Yes
# 4   323  5.702  266.28411    114619  0.073       161     Yes
# 5   324  5.702  280.26368    143801  0.073       161     Yes
# 6  2039  5.818  453.78492    102491  0.091       936     Yes
# 7  1201  6.957  326.37808    188914  0.145       425     Yes
# 8   326  7.355  266.28417    167286  0.472       162     Yes
# 9   327  7.355  280.26336    219464  0.472       162     Yes
#
#   Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm) Precursor Ion  \
# 0              ----      ----   ----        ----        ----          ----
# 1              ----      ----   ----        ----        ----          ----
# ...

# %%
df55.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0   917  1.689  326.37788    427237  0.091      2580     Yes
# 1   927  9.700  327.22774    292936  0.200      2583     Yes
# 2  1137  9.701  341.24362    368472  0.363      2698     Yes
# 3  1293  9.702  395.21593    119459  0.236      2810     Yes
# 4  1540  9.705  536.33086    448233  0.218      2992     Yes
# 5  1551  9.706  550.34690    307939  0.291      3000     Yes
# 6  1295  9.738  387.24901    174162  0.327      2811     Yes
# 7    19  9.750  156.10185    214890  0.382      2216     Yes
# 8   121  9.752  216.12283    110057  0.382      2265     Yes
# 9  1140  9.755  342.24514    123826  0.254      2699     Yes
#
#     Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# ...

# %%
df56.head(10)
# Out:
#       #     RT        m/z  Response  Width  RT Group Predict  \
# 0     2  1.593  118.08603    377137  0.164      6424     Yes
# 1     4  1.629  102.01271    112533  0.200      6425     Yes
# 2   119  2.284  171.11287    287951  0.472      6522     Yes
# 3     8  2.519  113.05933    355394  0.236      6428     Yes
# 4   125  5.100  174.05480    139944  0.636      6527     Yes
# 5    16  5.444  110.05983    528606  0.581      6434     Yes
# 6    19  5.607  110.05984    346280  0.327      6435     Yes
# 7  1314  6.396  384.18595    311187  0.382      7028     Yes
# 8    68  6.608  156.10166    163195  0.345      6479     Yes
# 9   172  6.863  188.07054    239030  0.472      6566     Yes
#
#     Predicted Formula Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0    [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1                ----      ----   ----        ----        ----      102.01271
# ...

# %%
df54.columns = (df54.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df55.columns = (df55.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df56.columns = (df56.columns.str.replace('RT', 'TR_MIN')
                .str.replace('m/z', 'FW')
                .str.replace('Predicted Formula', 'MF')
                .str.replace('Response', 'AREA_COUNTS'))

# %%
df54.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0  2002   1.639  462.82278       133688  0.091           906     Yes
# 1  1200   3.160  326.37776       229222  0.091           424     Yes
# 2  2038   5.491  453.78525       109714  0.091           935     Yes
# 3  2037   5.491  449.79079       163774  0.091           935     Yes
# 4   323   5.702  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df55.head()
# Out:
#       #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   917   1.689  326.37788       427237  0.091          2580     Yes
# 1   927   9.700  327.22774       292936  0.200          2583     Yes
# 2  1137   9.701  341.24362       368472  0.363          2698     Yes
# 3  1293   9.702  395.21593       119459  0.236          2810     Yes
# 4  1540   9.705  536.33086       448233  0.218          2992     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# 2  [C18 H32 N2 O4+H]+     55.48  49.77        0.14        0.41      341.24362
# 3    [C18 H29 N5 O5]+     83.35  84.56       -0.39      -0.987      395.21593
# 4      [C23 H36 N16]+     55.63  49.63        0.52        0.97      536.33086
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df56.head()
# Out:
#      #  TR_MIN         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0    2   1.593  118.08603       377137  0.164          6424     Yes
# 1    4   1.629  102.01271       112533  0.200          6425     Yes
# 2  119   2.284  171.11287       287951  0.472          6522     Yes
# 3    8   2.519  113.05933       355394  0.236          6428     Yes
# 4  125   5.100  174.05480       139944  0.636          6527     Yes
#
#                   MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1               ----      ----   ----        ----        ----      102.01271
# 2  [C8 H14 N2 O2+H]+     99.68  99.55        0.07       0.409      171.11287
# 3      [C6 H8 O2+H]+     54.35  46.56       -0.38      -3.361      113.05933
# 4   [C10 H7 N O2+H]+     55.56  49.62       -0.15      -0.862      174.05480
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df54.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df54.reset_index(inplace=True)

# %%
df54.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.639  2002  462.82278       133688  0.091           906     Yes
# 1   3.160  1200  326.37776       229222  0.091           424     Yes
# 2   5.491  2038  453.78525       109714  0.091           935     Yes
# 3   5.491  2037  449.79079       163774  0.091           935     Yes
# 4   5.702   323  266.28411       114619  0.073           161     Yes
#
#              MF Iso Score Score Diff. (mDa) Diff. (ppm) Precursor Ion  Event  \
# 0          ----      ----  ----        ----        ----          ----     22
# 1          ----      ----  ----        ----        ----          ----     13
# 2          ----      ----  ----        ----        ----          ----     23
# 3          ----      ----  ----        ----        ----          ----     23
# 4  [C18 H36 N]+      ----  ----       -0.12      -0.451     280.26368     10
#
#   Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df55.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df55.reset_index(inplace=True)

# %%
df55.head()
# Out:
#    TR_MIN     #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.689   917  326.37788       427237  0.091          2580     Yes
# 1   9.700   927  327.22774       292936  0.200          2583     Yes
# 2   9.701  1137  341.24362       368472  0.363          2698     Yes
# 3   9.702  1293  395.21593       119459  0.236          2810     Yes
# 4   9.705  1540  536.33086       448233  0.218          2992     Yes
#
#                    MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0      [C22 H47 N+H]+     69.08  71.83       -0.25      -0.766      326.37788
# 1  [C17 H30 N2 O4+H]+     75.36  77.72       -0.09      -0.275      327.22774
# 2  [C18 H32 N2 O4+H]+     55.48  49.77        0.14        0.41      341.24362
# 3    [C18 H29 N5 O5]+     83.35  84.56       -0.39      -0.987      395.21593
# 4      [C23 H36 N16]+     55.63  49.63        0.52        0.97      536.33086
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
# Set TR_MIN as index for dataframe

df56.set_index('TR_MIN', inplace=True)

# %%
# Reset index to convert 'TR_MIN' back to a regular column
df56.reset_index(inplace=True)

# %%
df56.head()
# Out:
#    TR_MIN    #         FW  AREA_COUNTS  Width  TR_MIN Group Predict  \
# 0   1.593    2  118.08603       377137  0.164          6424     Yes
# 1   1.629    4  102.01271       112533  0.200          6425     Yes
# 2   2.284  119  171.11287       287951  0.472          6522     Yes
# 3   2.519    8  113.05933       355394  0.236          6428     Yes
# 4   5.100  125  174.05480       139944  0.636          6527     Yes
#
#                   MF Iso Score  Score Diff. (mDa) Diff. (ppm)  Precursor Ion  \
# 0   [C5 H11 N O2+H]+     99.82   98.8       -0.23      -1.948      118.08603
# 1               ----      ----   ----        ----        ----      102.01271
# 2  [C8 H14 N2 O2+H]+     99.68  99.55        0.07       0.409      171.11287
# 3      [C6 H8 O2+H]+     54.35  46.56       -0.38      -3.361      113.05933
# 4   [C10 H7 N O2+H]+     55.56  49.62       -0.15      -0.862      174.05480
#
#    Event Target Name Target Formula Target FW Target TR_MIN Mass Error (ppm)  \
# ...

# %%
df54.index
# Out:
# RangeIndex(start=0, stop=2304, step=1)

# %%
df55.index
# Out:
# RangeIndex(start=0, stop=179, step=1)

# %%
df56.index
# Out:
# RangeIndex(start=0, stop=384, step=1)

# %%
df54.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df55.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
df56.columns
# Out:
# Index(['TR_MIN', '#', 'FW', 'AREA_COUNTS', 'Width', 'TR_MIN Group', 'Predict',
#        'MF', 'Iso Score', 'Score', 'Diff. (mDa)', 'Diff. (ppm)',
#        'Precursor Ion', 'Event', 'Target Name', 'Target Formula', 'Target FW',
#        'Target TR_MIN', 'Mass Error (ppm)', 'Mass Error (mDa)'],
#       dtype='object')

# %%
# Select the required columns for the new DataFrame
df54 = df54[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df54.head()
# Out:
#    TR_MIN  AREA_COUNTS            MF         FW
# 0   1.639       133688          ----  462.82278
# 1   3.160       229222          ----  326.37776
# 2   5.491       109714          ----  453.78525
# 3   5.491       163774          ----  449.79079
# 4   5.702       114619  [C18 H36 N]+  266.28411

# %%
# Select the required columns for the new DataFrame
df55 = df55[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df55.head()
# Out:
#    TR_MIN  AREA_COUNTS                  MF         FW
# 0   1.689       427237      [C22 H47 N+H]+  326.37788
# 1   9.700       292936  [C17 H30 N2 O4+H]+  327.22774
# 2   9.701       368472  [C18 H32 N2 O4+H]+  341.24362
# 3   9.702       119459    [C18 H29 N5 O5]+  395.21593
# 4   9.705       448233      [C23 H36 N16]+  536.33086

# %%
# Select the required columns for the new DataFrame
df56 = df56[['TR_MIN', 'AREA_COUNTS', 'MF', 'FW']]

# %%
df56.head()
# Out:
#    TR_MIN  AREA_COUNTS                 MF         FW
# 0   1.593       377137   [C5 H11 N O2+H]+  118.08603
# 1   1.629       112533               ----  102.01271
# 2   2.284       287951  [C8 H14 N2 O2+H]+  171.11287
# 3   2.519       355394      [C6 H8 O2+H]+  113.05933
# 4   5.100       139944   [C10 H7 N O2+H]+  174.05480

# %%
df54.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TR_MIN       2304 non-null   float64
#  1   AREA_COUNTS  2304 non-null   int64
#  2   MF           2304 non-null   object
#  3   FW           2304 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 72.1+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Plotting
plt.scatter(df54['FW'], df54['AREA_COUNTS'], label='-ve AMRUN POS', color='blue')
plt.scatter(df55['FW'], df55['AREA_COUNTS'], label='-ve AMRUN 350oC POS', color='red')
plt.scatter(df56['FW'], df56['AREA_COUNTS'], label='-ve MICROWAVE POS', color='green')


# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Area Counts')
plt.title('Combined Scatter Plot of Area Counts vs FW')
plt.legend()

# Show plot
plt.show()

# %%
# Dataframes (df54, df55, df56)


# Bin the FW values in increments of 25 and sum the AREA_COUNTS within each bin for each dataset
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

df54_binned = bin_and_sum(df54)
df55_binned = bin_and_sum(df55)
df56_binned = bin_and_sum(df56)

# Plot the binned sums versus 'FW'
plt.plot(df54_binned['FW_bin'], df54_binned['AREA_COUNTS'], label='-ve AMRUN POS', color='blue', marker='o')
plt.plot(df55_binned['FW_bin'], df55_binned['AREA_COUNTS'], label='-ve AMRUN 350oC POS', color='red', marker='o')
plt.plot(df56_binned['FW_bin'], df56_binned['AREA_COUNTS'], label='-ve MICROWAVE POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_21604\895743656.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_21604\895743656.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
# Check format of the columns df54
df54.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df55
df55.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %%
# Check format of the columns df56
df56.columns
# Out:
# Index(['TR_MIN', 'AREA_COUNTS', 'MF', 'FW', 'FW_bin'], dtype='object')

# %% [markdown]
# ### Weighted bins of 25 Plots

# %%
# Function to bin the FW values and sum AREA_COUNTS within each bin
def bin_and_sum(df, bin_size=25):
    bins = np.arange(df['FW'].min(), df['FW'].max() + bin_size, bin_size)
    df['FW_bin'] = pd.cut(df['FW'], bins=bins, labels=bins[:-1])
    binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
    return binned_data

# Binning the dataframes
df54_binned = bin_and_sum(df54)
df55_binned = bin_and_sum(df55)
df56_binned = bin_and_sum(df56)

# Applying the scaling factors
df54_binned['AREA_COUNTS'] *= 1.000
df55_binned['AREA_COUNTS'] *= 0.4995
df56_binned['AREA_COUNTS'] *= 0.0518

# Plotting the binned and scaled sums versus 'FW'
plt.plot(df54_binned['FW_bin'], df54_binned['AREA_COUNTS'], label='-ve AMRUN POS', color='blue', marker='o')
plt.plot(df55_binned['FW_bin'], df55_binned['AREA_COUNTS'], label='-ve AMRUN 350oC POS', color='red', marker='o')
plt.plot(df56_binned['FW_bin'], df56_binned['AREA_COUNTS'], label='-ve MICROWAVE POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_21604\1824709001.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# C:\Users\jonathan.thabano\AppData\Local\Temp\ipykernel_21604\1824709001.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_data = df.groupby('FW_bin')['AREA_COUNTS'].sum().reset_index()
# ...

# %%
#Check the summary of binned data for df54
df54_binned.head(27)
# Out:
#        FW_bin  AREA_COUNTS
# 0    41.02563    3482428.0
# 1    66.02563   41217646.0
# 2    91.02563   74557855.0
# 3   116.02563   47842495.0
# 4   141.02563   48485987.0
# 5   166.02563   35349165.0
# 6   191.02563   14151970.0
# 7   216.02563   21650856.0
# 8   241.02563   81826610.0
# 9   266.02563  109370912.0
# 10  291.02563   82911893.0
# 11  316.02563  113738192.0
# 12  341.02563   39774398.0
# 13  366.02563   23676489.0
# 14  391.02563    6873903.0
# 15  416.02563   10782516.0
# 16  441.02563    9772563.0
# 17  466.02563   11076949.0
# 18  491.02563   12145166.0
# 19  516.02563    5285609.0
# 20  541.02563    4956488.0
# 21  566.02563    3089044.0
# 22  591.02563    6020777.0
# 23  616.02563    5471390.0
# 24  641.02563    4481863.0
# 25  666.02563    1410676.0
# 26  691.02563    2997172.0

# %%
#Check the summary of binned data for df55
df55_binned.head(26)
# Out:
#        FW_bin   AREA_COUNTS
# 0   156.10185  6.658615e+05
# 1   181.10185  4.694021e+05
# 2   206.10185  3.919172e+05
# 3   231.10185  4.717967e+05
# 4   256.10185  2.071276e+07
# 5   281.10185  1.626047e+07
# 6   306.10185  1.599261e+07
# 7   331.10185  4.784816e+06
# 8   356.10185  2.036403e+06
# 9   381.10185  2.014398e+06
# 10  406.10185  4.695245e+05
# 11  431.10185  5.674755e+05
# 12  456.10185  9.329181e+05
# 13  481.10185  1.065277e+06
# 14  506.10185  1.222356e+05
# 15  531.10185  3.777079e+05
# 16  556.10185  6.921247e+05
# 17  581.10185  1.431823e+06
# 18  606.10185  4.023677e+05
# 19  631.10185  3.560781e+05
# 20  656.10185  4.332373e+05
# 21  681.10185  9.720670e+04
# 22  706.10185  3.414567e+05

# %%
#Check the summary of binned data for df56
df56_binned.head(26)
# Out:
#        FW_bin   AREA_COUNTS
# 0   102.01271  9.591801e+04
# 1   127.01271  6.939501e+04
# 2   152.01271  8.808248e+04
# 3   177.01271  6.835559e+04
# 4   202.01271  2.833621e+04
# 5   227.01271  7.397429e+04
# 6   252.01271  2.576263e+05
# 7   277.01271  1.256159e+06
# 8   302.01271  1.923720e+06
# 9   327.01271  1.154992e+06
# 10  352.01271  1.160815e+06
# 11  377.01271  8.682029e+05
# 12  402.01271  3.984259e+05
# 13  427.01271  6.469095e+05
# 14  452.01271  6.753942e+05
# 15  477.01271  7.806968e+05
# 16  502.01271  3.054008e+05
# 17  527.01271  5.718562e+05
# 18  552.01271  4.356840e+05
# 19  577.01271  6.285476e+05
# 20  602.01271  2.558732e+05
# 21  627.01271  2.950230e+05
# 22  652.01271  4.512228e+05
# 23  677.01271  1.587978e+05
# 24  702.01271  8.446166e+05
# 25  727.01271  7.021335e+05

# %%
#New dataframe of df54 binned data by dropping row [0] and row [13] 
df54_binned = df54_binned.drop([2,8,9,10,11])

# %%
#New dataframe of df32 binned data by dropping row [0] and row [13] 
#df55_binned = df55_binned.drop([0,13])

# %%
#New dataframe of df33 binned data by dropping row [0] and row [13] 
#df56_binned = df56_binned.drop([0,13])

# %%
#Check if drop() function worked by calling df54.head() again
df54_binned.head(25)
# Out:
#        FW_bin  AREA_COUNTS
# 0    41.02563    3482428.0
# 1    66.02563   41217646.0
# 3   116.02563   47842495.0
# 4   141.02563   48485987.0
# 5   166.02563   35349165.0
# 6   191.02563   14151970.0
# 7   216.02563   21650856.0
# 12  341.02563   39774398.0
# 13  366.02563   23676489.0
# 14  391.02563    6873903.0
# 15  416.02563   10782516.0
# 16  441.02563    9772563.0
# 17  466.02563   11076949.0
# 18  491.02563   12145166.0
# 19  516.02563    5285609.0
# 20  541.02563    4956488.0
# 21  566.02563    3089044.0
# 22  591.02563    6020777.0
# 23  616.02563    5471390.0
# 24  641.02563    4481863.0
# 25  666.02563    1410676.0
# 26  691.02563    2997172.0
# 27  716.02563     616060.0
# 28  741.02563     128319.0

# %%
#Check if drop() function worked by calling df55.head() again
#df55_binned.head(25)

# %%
#Check if drop() function worked by calling df56.head() again
#df56_binned.head(25)

# %%
# Plotting the binned and scaled sums versus 'FW' of adusjted graphs
plt.plot(df54_binned['FW_bin'], df54_binned['AREA_COUNTS'], label='-ve AMRUN POS', color='blue', marker='o')
plt.plot(df55_binned['FW_bin'], df55_binned['AREA_COUNTS'], label='-ve AMRUN 350oC POS', color='red', marker='o')
plt.plot(df56_binned['FW_bin'], df56_binned['AREA_COUNTS'], label='-ve MICROWAVE POS', color='green', marker='o')

# Adding labels and legend
plt.xlabel('FW')
plt.ylabel('Sum of Area Counts')
plt.title('Sum of Area Counts in Bins of 25 vs FW')
plt.legend()

# Show plot
plt.show()
